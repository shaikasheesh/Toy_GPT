# %%
#importing all the libraries
import torch
import torch.nn as nn
import torch.nn.functional as F
from warnings import filterwarnings
filterwarnings('ignore')

# %%
#config
input_file_path = 'data/input.txt' #reading the input text file
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'currently running on: {device}')
batch_size = 16
block_size = 256 #context lenght
n_emb = 128
num_heads = 6 
n_layers = 6
dropout = 0.0
learning_rate = 1e-3 
min_lr = learning_rate * 0.1
max_steps = 2000
lr_decay_iters = max_steps
eval_interval = 250
KFold_iters = 100
# top_k = 200
# temperature = 0.1
# Out:
# currently running on: cuda

# %%
#for reproducibility
torch.manual_seed(1337)
torch.cuda.manual_seed(1337)
torch.cuda.empty_cache()

# %%
#reading the dataset for pretraining

with open(input_file_path , 'r') as f:
    text = f.read()
n1 = int(0.9*len(text))
chars = sorted(set(text))
vocab_size = len(chars)
stoi = {ch:i for i,ch in enumerate(chars)}
itos = {i:ch for i,ch in enumerate(chars)}
encoder = lambda x: [stoi[ch] for ch in x]
decoder = lambda x: ''.join([itos[i] for i in x])

data = torch.tensor(encoder(text),dtype = torch.long,device=device)

# %%
#splitting train and test & creating data loading batch
n1 = int(0.8*len(data))
n2 = int(0.9*len(data))
train_data = data[:n1]
dev_data = data[n1:n2]
test_data = data[n2:]

def get_batch(split):
    if split == 'train':
        data = train_data
    elif split == 'val':
        data = dev_data
    elif split == 'test':
        data = test_data
    ix = torch.randint(0, len(data) - block_size,(batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1: i+block_size + 1] for i in ix])
    x,y = x.to(device) , y.to(device)
    return x,y

# %%
no_of_batches_in_epoch = len(train_data) // (batch_size*block_size)
print('no of bathces in an epoch:',no_of_batches_in_epoch )
# Out:
# no of bathces in an epoch: 217

# %%
#model definition: GPT model
class Head(nn.Module):
    def __init__(self,head_size):
        super().__init__()
        self.key = nn.Linear(n_emb,head_size, bias = False)
        self.query = nn.Linear(n_emb,head_size, bias = False)
        self.value = nn.Linear(n_emb,head_size, bias = False)
        self.register_buffer('tril' , torch.tril(torch.ones(block_size,block_size)))
        self.dropout = nn.Dropout(dropout)
    
    def forward(self,x):
        B,T,C = x.shape
        k = self.key(x)
        q = self.query(x)
        v = self.value(x)
        # wei = q @ k.transpose(-2,-1) * k.shape[-1]**-0.5
        # wei = wei.masked_fill(self.tril[:T,:T] == 0, float('-inf'))
        # wei = F.softmax(wei, dim = -1)
        # wei = self.dropout(wei)
        # out = wei @ v
        out = F.scaled_dot_product_attention(q,k,v,is_causal= True) #flash attention
        return out

class MultiHeadAttention(nn.Module):
    def __init__(self,num_heads,head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for i in range(num_heads)])
        self.proj = nn.Linear(num_heads * head_size , n_emb)
        self.proj.NANO_GPT_INIT = 1
        self.dropout = nn.Dropout(dropout)

    def forward(self,x):
        out = torch.cat([h(x) for h in self.heads], dim = -1)
        out = self.dropout(self.proj(out))
        return out


class FeedForwardNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.NANO_GPT_INIT = 1
        self.net = nn.Sequential(
            nn.Linear(n_emb, 4 * n_emb),
            nn.ReLU())
        self.proj = nn.Linear(n_emb * 4, n_emb)
        self.proj.NANO_GPT_INIT = 1
        self.dropout = nn.Dropout(dropout)
        
    def forward(self,x):
        out = self.dropout(self.proj(self.net(x)))
        return out


class Block(nn.Module):
    def __init__(self,num_heads):
        super().__init__()
        head_size = n_emb // num_heads
        self.sa = MultiHeadAttention(num_heads,head_size)
        self.ff = FeedForwardNetwork()
        self.ln1 = nn.LayerNorm(n_emb)
        self.ln2 = nn.LayerNorm(n_emb)

    def forward(self,x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ff(self.ln2(x))
        return x
        

class GPTModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.embedding_table = nn.Embedding(vocab_size,n_emb)
        self.position_emb = nn.Embedding(block_size,n_emb)
        self.block = nn.Sequential(*[Block(num_heads) for i in range(n_layers)])
        self.ln = nn.LayerNorm(n_emb)
        self.lm_head = nn.Linear(n_emb,vocab_size)
        #weight sharing scheme
        self.embedding_table.weight = self.lm_head.weight
        self.apply(self._init_weights)
        
    def _init_weights(self,module):
        std = 0.02
        if isinstance(module,nn.Linear):
            if hasattr(module, 'NANO_GPT_INIT'):
                std = 2 * (n_layers**-0.5)
            torch.nn.init.normal_(module.weight, mean=0.0, std=std)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module,nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=std)

    
    def forward(self,idx,targets = None):
        B,T = idx.shape
        token_emb = self.embedding_table(idx)
        pos_emb = self.position_emb(torch.arange(T,device = device))
        x = token_emb + pos_emb
        x = self.block(x)
        x = self.ln(x)
        logits = self.lm_head(x)
        if targets is None:
            loss = None
        else:
            B,T,C = logits.shape
            logits = logits.view(B*T,C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits,targets)
        return logits,loss

    def generate(self,idx,max_new_tokens):
        for _ in range(max_new_tokens):
            idx_cond = idx[:,-block_size:]
            logits,loss = self.forward(idx_cond)
            logits = logits[:,-1,:] 
            probs = F.softmax(logits, dim =-1)
            #topk_probs, topk_indices = torch.topk(probs, top_k, dim = -1)
            idx_new = torch.multinomial(probs, num_samples = 1, replacement = False)
            idx = torch.cat((idx_cond,idx_new), dim = 1)
        return idx

# %%
#call the model and printing trainable model params
model = GPTModel()
model.to(device)
print(sum(p.numel() for p in model.parameters())/1e6, 'M parameters')
# Out:
# 1.222593 M parameters

# %%
#initializing optimier
optimizer = torch.optim.AdamW(model.parameters(),lr = learning_rate, betas=(0.9,0.95),weight_decay= 0.1)
epoch = 0

# %%
@torch.no_grad()
def estimate_loss():
    model.eval()
    out = {}
    for split in ['train','val']:
        losses = torch.zeros(KFold_iters)
        for i in range(KFold_iters):
            xb,yb = get_batch(split)
            logits,loss = model.forward(xb,yb)
            losses[i] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# %%
#training loop
for step in range(4):
    for i in range(max_steps):
        if i % no_of_batches_in_epoch == 0: 
            epoch +=1
        if i % eval_interval == 0:
            losses = estimate_loss()
            print(f"step {i}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")
        optimizer.zero_grad(set_to_none=True)
        x,y = get_batch('train')
        with torch.autocast(device_type=device,dtype = torch.float16):  
            logits , loss = model.forward(x,y)
        loss.backward()
        norm = nn.utils.clip_grad_norm_(model.parameters(),1) #gpt3 paper says
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer,max_steps,min_lr) #gpt 3 paper says
        optimizer.step()
        scheduler.step(i)
        torch.cuda.synchronize()
        print(f"step {i} | loss_acum:{loss.item():.6f} | lr: {scheduler.get_lr()[0]: .4e} | norm:{norm: .4f}")
        if i%200 == 0:
            context = torch.zeros(1,1 , dtype = torch.long, device = device)
            out = decoder(model.generate(context, 500).tolist()[0])
            print(out)
# Out:
# step 0: train loss 1.3741, val loss 1.5463
# step 0 | loss_acum:1.293981 | lr:  1.0000e-03 | norm: 1.0638
# me
# And eyeBurned in Hereford him?
#
# PRINCE EDWARD:
# Sorrow and his remourable,
# Thre teding of chastor'd my stay,
# Dire company bads, or death crowned the first
# Since this truth butters: sail those for butchiry,
# Fatces to the merry thy will one can under cleept
# step 1 | loss_acum:1.361403 | lr:  1.0000e-03 | norm: 1.0950
# step 2 | loss_acum:1.332302 | lr:  1.0000e-03 | norm: 1.8844
# step 3 | loss_acum:1.403914 | lr:  9.9999e-04 | norm: 1.7256
# step 4 | loss_acum:1.430158 | lr:  9.9999e-04 | norm: 1.7355
# step 5 | loss_acum:1.534000 | lr:  9.9998e-04 | norm: 1.5947
# step 6 | loss_acum:1.507087 | lr:  9.9997e-04 | norm: 1.5691
# step 7 | loss_acum:1.482707 | lr:  9.9997e-04 | norm: 1.6577
# step 8 | loss_acum:1.449585 | lr:  9.9996e-04 | norm: 1.5860
# step 9 | loss_acum:1.520351 | lr:  9.9995e-04 | norm: 1.7364
# step 10 | loss_acum:1.451004 | lr:  9.9993e-04 | norm: 1.4811
# step 11 | loss_acum:1.459981 | lr:  9.9992e-04 | norm: 1.6678
# step 12 | loss_acum:1.430313 | lr:  9.9991e-04 | norm: 1.6176
# step 13 | loss_acum:1.502674 | lr:  9.9989e-04 | norm: 1.3631
# step 14 | loss_acum:1.501607 | lr:  9.9988e-04 | norm: 1.5708
# step 15 | loss_acum:1.456948 | lr:  9.9986e-04 | norm: 1.4588
# step 16 | loss_acum:1.475230 | lr:  9.9984e-04 | norm: 1.6125
# step 17 | loss_acum:1.447191 | lr:  9.9982e-04 | norm: 1.4225
# step 18 | loss_acum:1.463768 | lr:  9.9980e-04 | norm: 1.7725
# step 19 | loss_acum:1.426434 | lr:  9.9978e-04 | norm: 1.5722
# step 20 | loss_acum:1.437227 | lr:  9.9976e-04 | norm: 1.5316
# step 21 | loss_acum:1.480286 | lr:  9.9973e-04 | norm: 1.7183
# step 22 | loss_acum:1.464264 | lr:  9.9971e-04 | norm: 1.6168
# step 23 | loss_acum:1.499836 | lr:  9.9968e-04 | norm: 1.4834
# step 24 | loss_acum:1.548416 | lr:  9.9965e-04 | norm: 1.8213
# step 25 | loss_acum:1.439135 | lr:  9.9963e-04 | norm: 1.4962
# step 26 | loss_acum:1.506395 | lr:  9.9960e-04 | norm: 1.3491
# step 27 | loss_acum:1.482658 | lr:  9.9957e-04 | norm: 1.4356
# step 28 | loss_acum:1.467724 | lr:  9.9953e-04 | norm: 1.3557
# step 29 | loss_acum:1.384191 | lr:  9.9950e-04 | norm: 1.3348
# step 30 | loss_acum:1.435903 | lr:  9.9947e-04 | norm: 1.2486
# step 31 | loss_acum:1.421781 | lr:  9.9943e-04 | norm: 1.2908
# step 32 | loss_acum:1.445156 | lr:  9.9940e-04 | norm: 1.4106
# step 33 | loss_acum:1.458492 | lr:  9.9936e-04 | norm: 1.4139
# step 34 | loss_acum:1.500041 | lr:  9.9932e-04 | norm: 1.4365
# step 35 | loss_acum:1.430722 | lr:  9.9928e-04 | norm: 1.4704
# step 36 | loss_acum:1.445931 | lr:  9.9924e-04 | norm: 1.4973
# step 37 | loss_acum:1.442904 | lr:  9.9920e-04 | norm: 1.3369
# step 38 | loss_acum:1.490193 | lr:  9.9916e-04 | norm: 1.5218
# step 39 | loss_acum:1.476416 | lr:  9.9911e-04 | norm: 1.3124
# step 40 | loss_acum:1.455302 | lr:  9.9907e-04 | norm: 1.6696
# step 41 | loss_acum:1.436498 | lr:  9.9902e-04 | norm: 1.2817
# step 42 | loss_acum:1.460714 | lr:  9.9897e-04 | norm: 1.3943
# step 43 | loss_acum:1.397225 | lr:  9.9893e-04 | norm: 1.3349
# step 44 | loss_acum:1.471903 | lr:  9.9888e-04 | norm: 1.2585
# step 45 | loss_acum:1.535122 | lr:  9.9883e-04 | norm: 1.4246
# step 46 | loss_acum:1.452826 | lr:  9.9878e-04 | norm: 1.1896
# step 47 | loss_acum:1.480914 | lr:  9.9872e-04 | norm: 1.2869
# step 48 | loss_acum:1.408399 | lr:  9.9867e-04 | norm: 1.2572
# step 49 | loss_acum:1.509752 | lr:  9.9861e-04 | norm: 1.3279
# step 50 | loss_acum:1.470432 | lr:  9.9856e-04 | norm: 1.0880
# step 51 | loss_acum:1.501994 | lr:  9.9850e-04 | norm: 1.2846
# step 52 | loss_acum:1.494183 | lr:  9.9844e-04 | norm: 1.4607
# step 53 | loss_acum:1.507404 | lr:  9.9838e-04 | norm: 1.2886
# step 54 | loss_acum:1.492398 | lr:  9.9832e-04 | norm: 1.3007
# step 55 | loss_acum:1.372711 | lr:  9.9826e-04 | norm: 1.2589
# step 56 | loss_acum:1.432320 | lr:  9.9820e-04 | norm: 1.1010
# step 57 | loss_acum:1.444767 | lr:  9.9813e-04 | norm: 1.2822
# step 58 | loss_acum:1.475421 | lr:  9.9807e-04 | norm: 1.3003
# step 59 | loss_acum:1.479771 | lr:  9.9800e-04 | norm: 1.4435
# step 60 | loss_acum:1.492488 | lr:  9.9794e-04 | norm: 1.3304
# step 61 | loss_acum:1.502043 | lr:  9.9787e-04 | norm: 1.2714
# step 62 | loss_acum:1.386433 | lr:  9.9780e-04 | norm: 1.2209
# step 63 | loss_acum:1.490238 | lr:  9.9773e-04 | norm: 1.2588
# step 64 | loss_acum:1.485045 | lr:  9.9766e-04 | norm: 1.2260
# step 65 | loss_acum:1.492328 | lr:  9.9758e-04 | norm: 1.2667
# step 66 | loss_acum:1.489468 | lr:  9.9751e-04 | norm: 1.2912
# step 67 | loss_acum:1.442927 | lr:  9.9744e-04 | norm: 1.1594
# step 68 | loss_acum:1.500930 | lr:  9.9736e-04 | norm: 1.2428
# step 69 | loss_acum:1.546838 | lr:  9.9728e-04 | norm: 1.2945
# step 70 | loss_acum:1.424334 | lr:  9.9721e-04 | norm: 1.2114
# step 71 | loss_acum:1.443847 | lr:  9.9713e-04 | norm: 1.1875
# step 72 | loss_acum:1.439281 | lr:  9.9705e-04 | norm: 1.2959
# step 73 | loss_acum:1.445999 | lr:  9.9696e-04 | norm: 1.2371
# step 74 | loss_acum:1.419660 | lr:  9.9688e-04 | norm: 1.2860
# step 75 | loss_acum:1.470250 | lr:  9.9680e-04 | norm: 1.2775
# step 76 | loss_acum:1.496610 | lr:  9.9671e-04 | norm: 1.3071
# step 77 | loss_acum:1.506983 | lr:  9.9663e-04 | norm: 1.2032
# step 78 | loss_acum:1.504434 | lr:  9.9654e-04 | norm: 1.4587
# step 79 | loss_acum:1.469483 | lr:  9.9645e-04 | norm: 1.3105
# step 80 | loss_acum:1.462302 | lr:  9.9636e-04 | norm: 1.5285
# step 81 | loss_acum:1.544714 | lr:  9.9627e-04 | norm: 1.4255
# step 82 | loss_acum:1.454075 | lr:  9.9618e-04 | norm: 1.5480
# step 83 | loss_acum:1.477597 | lr:  9.9609e-04 | norm: 1.4129
# step 84 | loss_acum:1.491287 | lr:  9.9600e-04 | norm: 1.5520
# step 85 | loss_acum:1.519793 | lr:  9.9590e-04 | norm: 1.7254
# step 86 | loss_acum:1.476991 | lr:  9.9581e-04 | norm: 1.1418
# step 87 | loss_acum:1.471120 | lr:  9.9571e-04 | norm: 1.5366
# step 88 | loss_acum:1.462761 | lr:  9.9561e-04 | norm: 1.3214
# step 89 | loss_acum:1.448264 | lr:  9.9551e-04 | norm: 1.3272
# step 90 | loss_acum:1.442720 | lr:  9.9541e-04 | norm: 1.3321
# step 91 | loss_acum:1.470631 | lr:  9.9531e-04 | norm: 1.3585
# step 92 | loss_acum:1.473056 | lr:  9.9521e-04 | norm: 1.2291
# step 93 | loss_acum:1.498609 | lr:  9.9510e-04 | norm: 1.3902
# step 94 | loss_acum:1.506184 | lr:  9.9500e-04 | norm: 1.2155
# step 95 | loss_acum:1.498854 | lr:  9.9489e-04 | norm: 1.2515
# step 96 | loss_acum:1.497492 | lr:  9.9479e-04 | norm: 1.3046
# step 97 | loss_acum:1.547352 | lr:  9.9468e-04 | norm: 1.3890
# step 98 | loss_acum:1.424895 | lr:  9.9457e-04 | norm: 1.1462
# step 99 | loss_acum:1.487964 | lr:  9.9446e-04 | norm: 1.2249
# step 100 | loss_acum:1.461056 | lr:  9.9435e-04 | norm: 1.2407
# step 101 | loss_acum:1.486985 | lr:  9.9424e-04 | norm: 1.2290
# step 102 | loss_acum:1.516023 | lr:  9.9412e-04 | norm: 1.2554
# step 103 | loss_acum:1.466233 | lr:  9.9401e-04 | norm: 1.2123
# step 104 | loss_acum:1.457980 | lr:  9.9389e-04 | norm: 1.1955
# step 105 | loss_acum:1.467080 | lr:  9.9378e-04 | norm: 1.4822
# step 106 | loss_acum:1.469349 | lr:  9.9366e-04 | norm: 1.2087
# step 107 | loss_acum:1.456918 | lr:  9.9354e-04 | norm: 1.3216
# step 108 | loss_acum:1.528343 | lr:  9.9342e-04 | norm: 1.2441
# step 109 | loss_acum:1.481000 | lr:  9.9330e-04 | norm: 1.3382
# step 110 | loss_acum:1.467811 | lr:  9.9318e-04 | norm: 1.3026
# step 111 | loss_acum:1.439022 | lr:  9.9306e-04 | norm: 1.0991
# step 112 | loss_acum:1.431835 | lr:  9.9293e-04 | norm: 1.1094
# step 113 | loss_acum:1.478903 | lr:  9.9281e-04 | norm: 1.3961
# step 114 | loss_acum:1.495860 | lr:  9.9268e-04 | norm: 1.2061
# step 115 | loss_acum:1.497325 | lr:  9.9255e-04 | norm: 1.1967
# step 116 | loss_acum:1.483790 | lr:  9.9242e-04 | norm: 1.2367
# step 117 | loss_acum:1.447160 | lr:  9.9229e-04 | norm: 1.1167
# step 118 | loss_acum:1.510854 | lr:  9.9216e-04 | norm: 1.1422
# step 119 | loss_acum:1.428722 | lr:  9.9203e-04 | norm: 1.2703
# step 120 | loss_acum:1.451368 | lr:  9.9190e-04 | norm: 1.2187
# step 121 | loss_acum:1.451328 | lr:  9.9176e-04 | norm: 1.2525
# step 122 | loss_acum:1.510165 | lr:  9.9163e-04 | norm: 1.4176
# step 123 | loss_acum:1.487977 | lr:  9.9149e-04 | norm: 1.1458
# step 124 | loss_acum:1.485991 | lr:  9.9135e-04 | norm: 1.3351
# step 125 | loss_acum:1.546661 | lr:  9.9122e-04 | norm: 1.3705
# step 126 | loss_acum:1.511849 | lr:  9.9108e-04 | norm: 1.1994
# step 127 | loss_acum:1.448008 | lr:  9.9094e-04 | norm: 1.2423
# step 128 | loss_acum:1.485932 | lr:  9.9079e-04 | norm: 1.1815
# step 129 | loss_acum:1.443620 | lr:  9.9065e-04 | norm: 1.2051
# step 130 | loss_acum:1.466455 | lr:  9.9051e-04 | norm: 1.1979
# step 131 | loss_acum:1.449167 | lr:  9.9036e-04 | norm: 1.3190
# step 132 | loss_acum:1.473209 | lr:  9.9022e-04 | norm: 1.5434
# step 133 | loss_acum:1.462641 | lr:  9.9007e-04 | norm: 1.2200
# step 134 | loss_acum:1.531519 | lr:  9.8992e-04 | norm: 1.3514
# step 135 | loss_acum:1.471376 | lr:  9.8977e-04 | norm: 1.2610
# step 136 | loss_acum:1.490615 | lr:  9.8962e-04 | norm: 1.3630
# step 137 | loss_acum:1.450034 | lr:  9.8947e-04 | norm: 1.2319
# step 138 | loss_acum:1.410469 | lr:  9.8932e-04 | norm: 1.0997
# step 139 | loss_acum:1.479051 | lr:  9.8916e-04 | norm: 1.3423
# step 140 | loss_acum:1.486480 | lr:  9.8901e-04 | norm: 1.3573
# step 141 | loss_acum:1.483040 | lr:  9.8885e-04 | norm: 1.2615
# step 142 | loss_acum:1.480547 | lr:  9.8870e-04 | norm: 1.2050
# step 143 | loss_acum:1.458348 | lr:  9.8854e-04 | norm: 1.2480
# step 144 | loss_acum:1.500400 | lr:  9.8838e-04 | norm: 1.2605
# step 145 | loss_acum:1.463497 | lr:  9.8822e-04 | norm: 1.3059
# step 146 | loss_acum:1.477458 | lr:  9.8806e-04 | norm: 1.2772
# step 147 | loss_acum:1.435690 | lr:  9.8790e-04 | norm: 1.1114
# step 148 | loss_acum:1.434110 | lr:  9.8773e-04 | norm: 1.0335
# step 149 | loss_acum:1.488703 | lr:  9.8757e-04 | norm: 1.2660
# step 150 | loss_acum:1.502198 | lr:  9.8740e-04 | norm: 1.1724
# step 151 | loss_acum:1.501622 | lr:  9.8724e-04 | norm: 1.1709
# step 152 | loss_acum:1.466532 | lr:  9.8707e-04 | norm: 1.1807
# step 153 | loss_acum:1.505055 | lr:  9.8690e-04 | norm: 1.1511
# step 154 | loss_acum:1.462755 | lr:  9.8673e-04 | norm: 1.1684
# step 155 | loss_acum:1.500506 | lr:  9.8656e-04 | norm: 1.2206
# step 156 | loss_acum:1.495617 | lr:  9.8639e-04 | norm: 1.1821
# step 157 | loss_acum:1.422502 | lr:  9.8621e-04 | norm: 1.1162
# step 158 | loss_acum:1.463812 | lr:  9.8604e-04 | norm: 1.1248
# step 159 | loss_acum:1.440880 | lr:  9.8586e-04 | norm: 1.1046
# step 160 | loss_acum:1.460064 | lr:  9.8569e-04 | norm: 1.2261
# step 161 | loss_acum:1.406569 | lr:  9.8551e-04 | norm: 1.1941
# step 162 | loss_acum:1.383553 | lr:  9.8533e-04 | norm: 1.1570
# step 163 | loss_acum:1.505188 | lr:  9.8515e-04 | norm: 1.2160
# step 164 | loss_acum:1.560786 | lr:  9.8497e-04 | norm: 1.1566
# step 165 | loss_acum:1.460247 | lr:  9.8479e-04 | norm: 1.3465
# step 166 | loss_acum:1.441553 | lr:  9.8461e-04 | norm: 1.1981
# step 167 | loss_acum:1.504097 | lr:  9.8442e-04 | norm: 1.1517
# step 168 | loss_acum:1.524149 | lr:  9.8424e-04 | norm: 1.3426
# step 169 | loss_acum:1.478971 | lr:  9.8405e-04 | norm: 1.2369
# step 170 | loss_acum:1.452376 | lr:  9.8386e-04 | norm: 1.1782
# step 171 | loss_acum:1.502463 | lr:  9.8368e-04 | norm: 1.0827
# step 172 | loss_acum:1.474417 | lr:  9.8349e-04 | norm: 1.3811
# step 173 | loss_acum:1.487939 | lr:  9.8330e-04 | norm: 1.1976
# step 174 | loss_acum:1.434951 | lr:  9.8311e-04 | norm: 1.0867
# step 175 | loss_acum:1.473292 | lr:  9.8291e-04 | norm: 1.3192
# step 176 | loss_acum:1.482587 | lr:  9.8272e-04 | norm: 1.1114
# step 177 | loss_acum:1.513802 | lr:  9.8253e-04 | norm: 1.2081
# step 178 | loss_acum:1.451565 | lr:  9.8233e-04 | norm: 1.1438
# step 179 | loss_acum:1.455737 | lr:  9.8213e-04 | norm: 1.0903
# step 180 | loss_acum:1.424668 | lr:  9.8194e-04 | norm: 1.0921
# step 181 | loss_acum:1.549074 | lr:  9.8174e-04 | norm: 1.4164
# step 182 | loss_acum:1.428039 | lr:  9.8154e-04 | norm: 1.1554
# step 183 | loss_acum:1.466691 | lr:  9.8134e-04 | norm: 1.3769
# step 184 | loss_acum:1.423006 | lr:  9.8113e-04 | norm: 1.1347
# step 185 | loss_acum:1.400994 | lr:  9.8093e-04 | norm: 1.1189
# step 186 | loss_acum:1.454636 | lr:  9.8073e-04 | norm: 1.1242
# step 187 | loss_acum:1.469040 | lr:  9.8052e-04 | norm: 1.1300
# step 188 | loss_acum:1.413464 | lr:  9.8032e-04 | norm: 1.2825
# step 189 | loss_acum:1.417254 | lr:  9.8011e-04 | norm: 1.2886
# step 190 | loss_acum:1.445147 | lr:  9.7990e-04 | norm: 1.2672
# step 191 | loss_acum:1.511904 | lr:  9.7969e-04 | norm: 1.2450
# step 192 | loss_acum:1.497663 | lr:  9.7948e-04 | norm: 1.3316
# step 193 | loss_acum:1.446729 | lr:  9.7927e-04 | norm: 1.1955
# step 194 | loss_acum:1.496064 | lr:  9.7906e-04 | norm: 1.2399
# step 195 | loss_acum:1.470070 | lr:  9.7884e-04 | norm: 1.1722
# step 196 | loss_acum:1.514525 | lr:  9.7863e-04 | norm: 1.1016
# step 197 | loss_acum:1.517199 | lr:  9.7841e-04 | norm: 1.2166
# step 198 | loss_acum:1.452683 | lr:  9.7819e-04 | norm: 1.1171
# step 199 | loss_acum:1.503765 | lr:  9.7798e-04 | norm: 1.1917
# step 200 | loss_acum:1.458441 | lr:  9.7776e-04 | norm: 1.0423
# ET:
# This rightrace selvoon consuments, strakes
# I, no firmide comfortion. I stecw not whithe,
# Are makeer I have thy time would-besws'd cheem
# Forth in a shelt of good rink son.
#
# So Mayor:
# You to.
#
# SIC:
# Wert, dismallord and look'd in:
# Why, thy 'gervile and is
# step 201 | loss_acum:1.471613 | lr:  9.7754e-04 | norm: 1.1250
# step 202 | loss_acum:1.451205 | lr:  9.7732e-04 | norm: 1.1263
# step 203 | loss_acum:1.477198 | lr:  9.7709e-04 | norm: 1.1387
# step 204 | loss_acum:1.474110 | lr:  9.7687e-04 | norm: 1.2403
# step 205 | loss_acum:1.430077 | lr:  9.7665e-04 | norm: 1.0021
# step 206 | loss_acum:1.455268 | lr:  9.7642e-04 | norm: 1.3375
# step 207 | loss_acum:1.472273 | lr:  9.7620e-04 | norm: 1.0725
# step 208 | loss_acum:1.418524 | lr:  9.7597e-04 | norm: 1.1891
# step 209 | loss_acum:1.405249 | lr:  9.7574e-04 | norm: 1.1700
# step 210 | loss_acum:1.518094 | lr:  9.7551e-04 | norm: 1.2863
# step 211 | loss_acum:1.456037 | lr:  9.7528e-04 | norm: 1.1362
# step 212 | loss_acum:1.513950 | lr:  9.7505e-04 | norm: 1.2031
# step 213 | loss_acum:1.456222 | lr:  9.7482e-04 | norm: 1.1074
# step 214 | loss_acum:1.496926 | lr:  9.7458e-04 | norm: 1.1683
# step 215 | loss_acum:1.506466 | lr:  9.7435e-04 | norm: 1.3069
# step 216 | loss_acum:1.582306 | lr:  9.7411e-04 | norm: 1.3548
# step 217 | loss_acum:1.472955 | lr:  9.7387e-04 | norm: 1.3626
# step 218 | loss_acum:1.450125 | lr:  9.7364e-04 | norm: 1.0446
# step 219 | loss_acum:1.420600 | lr:  9.7340e-04 | norm: 1.1184
# step 220 | loss_acum:1.469951 | lr:  9.7316e-04 | norm: 1.1153
# step 221 | loss_acum:1.459148 | lr:  9.7292e-04 | norm: 1.1912
# step 222 | loss_acum:1.443340 | lr:  9.7267e-04 | norm: 1.0931
# step 223 | loss_acum:1.403874 | lr:  9.7243e-04 | norm: 1.1483
# step 224 | loss_acum:1.445605 | lr:  9.7219e-04 | norm: 1.0975
# step 225 | loss_acum:1.430405 | lr:  9.7194e-04 | norm: 1.0697
# step 226 | loss_acum:1.419874 | lr:  9.7170e-04 | norm: 1.2991
# step 227 | loss_acum:1.427581 | lr:  9.7145e-04 | norm: 1.0718
# step 228 | loss_acum:1.447246 | lr:  9.7120e-04 | norm: 1.0017
# step 229 | loss_acum:1.429956 | lr:  9.7095e-04 | norm: 1.3529
# step 230 | loss_acum:1.511317 | lr:  9.7070e-04 | norm: 1.1146
# step 231 | loss_acum:1.425068 | lr:  9.7045e-04 | norm: 1.0626
# step 232 | loss_acum:1.472066 | lr:  9.7020e-04 | norm: 1.3052
# step 233 | loss_acum:1.457580 | lr:  9.6994e-04 | norm: 1.0751
# step 234 | loss_acum:1.532102 | lr:  9.6969e-04 | norm: 1.2066
# step 235 | loss_acum:1.537483 | lr:  9.6943e-04 | norm: 1.1884
# step 236 | loss_acum:1.400953 | lr:  9.6918e-04 | norm: 1.0749
# step 237 | loss_acum:1.494832 | lr:  9.6892e-04 | norm: 1.1657
# step 238 | loss_acum:1.484274 | lr:  9.6866e-04 | norm: 1.1388
# step 239 | loss_acum:1.404730 | lr:  9.6840e-04 | norm: 1.2610
# step 240 | loss_acum:1.472282 | lr:  9.6814e-04 | norm: 1.1522
# step 241 | loss_acum:1.474528 | lr:  9.6788e-04 | norm: 1.1868
# step 242 | loss_acum:1.436661 | lr:  9.6762e-04 | norm: 1.1974
# step 243 | loss_acum:1.502021 | lr:  9.6735e-04 | norm: 1.2641
# step 244 | loss_acum:1.473178 | lr:  9.6709e-04 | norm: 1.3393
# step 245 | loss_acum:1.478305 | lr:  9.6682e-04 | norm: 1.2837
# step 246 | loss_acum:1.462822 | lr:  9.6655e-04 | norm: 1.2718
# step 247 | loss_acum:1.500001 | lr:  9.6629e-04 | norm: 1.1528
# step 248 | loss_acum:1.462638 | lr:  9.6602e-04 | norm: 1.2747
# step 249 | loss_acum:1.473567 | lr:  9.6575e-04 | norm: 1.1196
# step 250: train loss 1.4705, val loss 1.6254
# step 250 | loss_acum:1.403117 | lr:  9.6548e-04 | norm: 1.1794
# step 251 | loss_acum:1.439314 | lr:  9.6520e-04 | norm: 1.1658
# step 252 | loss_acum:1.451046 | lr:  9.6493e-04 | norm: 1.1346
# step 253 | loss_acum:1.565892 | lr:  9.6466e-04 | norm: 1.3322
# step 254 | loss_acum:1.439745 | lr:  9.6438e-04 | norm: 1.1630
# step 255 | loss_acum:1.529738 | lr:  9.6411e-04 | norm: 1.3379
# step 256 | loss_acum:1.453256 | lr:  9.6383e-04 | norm: 1.2879
# step 257 | loss_acum:1.460769 | lr:  9.6355e-04 | norm: 1.3672
# step 258 | loss_acum:1.497171 | lr:  9.6327e-04 | norm: 1.2593
# step 259 | loss_acum:1.450514 | lr:  9.6299e-04 | norm: 1.3568
# step 260 | loss_acum:1.473187 | lr:  9.6271e-04 | norm: 1.1590
# step 261 | loss_acum:1.484675 | lr:  9.6243e-04 | norm: 1.1376
# step 262 | loss_acum:1.532406 | lr:  9.6214e-04 | norm: 1.2516
# step 263 | loss_acum:1.524639 | lr:  9.6186e-04 | norm: 1.0207
# step 264 | loss_acum:1.544219 | lr:  9.6157e-04 | norm: 1.0941
# step 265 | loss_acum:1.452788 | lr:  9.6129e-04 | norm: 1.1488
# step 266 | loss_acum:1.484235 | lr:  9.6100e-04 | norm: 1.1716
# step 267 | loss_acum:1.451519 | lr:  9.6071e-04 | norm: 1.3256
# step 268 | loss_acum:1.483603 | lr:  9.6042e-04 | norm: 1.1881
# step 269 | loss_acum:1.429863 | lr:  9.6013e-04 | norm: 1.2374
# step 270 | loss_acum:1.458723 | lr:  9.5984e-04 | norm: 1.0782
# step 271 | loss_acum:1.507723 | lr:  9.5955e-04 | norm: 1.2462
# step 272 | loss_acum:1.434539 | lr:  9.5926e-04 | norm: 1.2619
# step 273 | loss_acum:1.457209 | lr:  9.5896e-04 | norm: 1.1855
# step 274 | loss_acum:1.345001 | lr:  9.5867e-04 | norm: 1.1605
# step 275 | loss_acum:1.491496 | lr:  9.5837e-04 | norm: 1.1104
# step 276 | loss_acum:1.541831 | lr:  9.5807e-04 | norm: 1.3719
# step 277 | loss_acum:1.466450 | lr:  9.5777e-04 | norm: 1.1120
# step 278 | loss_acum:1.451297 | lr:  9.5747e-04 | norm: 1.1413
# step 279 | loss_acum:1.415474 | lr:  9.5717e-04 | norm: 1.1000
# step 280 | loss_acum:1.457346 | lr:  9.5687e-04 | norm: 1.1665
# step 281 | loss_acum:1.456396 | lr:  9.5657e-04 | norm: 1.1018
# step 282 | loss_acum:1.537124 | lr:  9.5627e-04 | norm: 1.1758
# step 283 | loss_acum:1.370206 | lr:  9.5596e-04 | norm: 1.1014
# step 284 | loss_acum:1.424150 | lr:  9.5566e-04 | norm: 1.1893
# step 285 | loss_acum:1.519587 | lr:  9.5535e-04 | norm: 1.1663
# step 286 | loss_acum:1.508298 | lr:  9.5504e-04 | norm: 1.2777
# step 287 | loss_acum:1.386512 | lr:  9.5473e-04 | norm: 1.0290
# step 288 | loss_acum:1.493472 | lr:  9.5442e-04 | norm: 1.2590
# step 289 | loss_acum:1.569779 | lr:  9.5411e-04 | norm: 1.0884
# step 290 | loss_acum:1.471344 | lr:  9.5380e-04 | norm: 1.1333
# step 291 | loss_acum:1.454382 | lr:  9.5349e-04 | norm: 1.2163
# step 292 | loss_acum:1.443567 | lr:  9.5318e-04 | norm: 1.1586
# step 293 | loss_acum:1.475462 | lr:  9.5286e-04 | norm: 1.1858
# step 294 | loss_acum:1.400488 | lr:  9.5255e-04 | norm: 1.1946
# step 295 | loss_acum:1.404506 | lr:  9.5223e-04 | norm: 1.0776
# step 296 | loss_acum:1.479661 | lr:  9.5191e-04 | norm: 1.2189
# step 297 | loss_acum:1.479996 | lr:  9.5159e-04 | norm: 1.2929
# step 298 | loss_acum:1.491191 | lr:  9.5127e-04 | norm: 1.1462
# step 299 | loss_acum:1.428723 | lr:  9.5095e-04 | norm: 1.1290
# step 300 | loss_acum:1.450916 | lr:  9.5063e-04 | norm: 1.1083
# step 301 | loss_acum:1.510141 | lr:  9.5031e-04 | norm: 1.3072
# step 302 | loss_acum:1.456014 | lr:  9.4999e-04 | norm: 1.0467
# step 303 | loss_acum:1.473848 | lr:  9.4966e-04 | norm: 1.0440
# step 304 | loss_acum:1.445061 | lr:  9.4934e-04 | norm: 1.0197
# step 305 | loss_acum:1.508270 | lr:  9.4901e-04 | norm: 1.1632
# step 306 | loss_acum:1.495383 | lr:  9.4868e-04 | norm: 1.2361
# step 307 | loss_acum:1.469635 | lr:  9.4836e-04 | norm: 1.0838
# step 308 | loss_acum:1.425851 | lr:  9.4803e-04 | norm: 1.2011
# step 309 | loss_acum:1.457052 | lr:  9.4770e-04 | norm: 1.0174
# step 310 | loss_acum:1.436567 | lr:  9.4736e-04 | norm: 1.0507
# step 311 | loss_acum:1.468052 | lr:  9.4703e-04 | norm: 0.9392
# step 312 | loss_acum:1.540258 | lr:  9.4670e-04 | norm: 1.0884
# step 313 | loss_acum:1.461598 | lr:  9.4636e-04 | norm: 1.2118
# step 314 | loss_acum:1.430531 | lr:  9.4603e-04 | norm: 0.9935
# step 315 | loss_acum:1.417822 | lr:  9.4569e-04 | norm: 1.1277
# step 316 | loss_acum:1.425489 | lr:  9.4536e-04 | norm: 1.0070
# step 317 | loss_acum:1.558818 | lr:  9.4502e-04 | norm: 1.1293
# step 318 | loss_acum:1.420805 | lr:  9.4468e-04 | norm: 1.0310
# step 319 | loss_acum:1.476260 | lr:  9.4434e-04 | norm: 1.0848
# step 320 | loss_acum:1.428828 | lr:  9.4400e-04 | norm: 1.0463
# step 321 | loss_acum:1.415846 | lr:  9.4366e-04 | norm: 1.1029
# step 322 | loss_acum:1.432804 | lr:  9.4331e-04 | norm: 1.0990
# step 323 | loss_acum:1.492857 | lr:  9.4297e-04 | norm: 1.0611
# step 324 | loss_acum:1.463635 | lr:  9.4262e-04 | norm: 1.1643
# step 325 | loss_acum:1.458274 | lr:  9.4228e-04 | norm: 1.1827
# step 326 | loss_acum:1.434863 | lr:  9.4193e-04 | norm: 1.0491
# step 327 | loss_acum:1.381705 | lr:  9.4158e-04 | norm: 1.0566
# step 328 | loss_acum:1.419925 | lr:  9.4124e-04 | norm: 1.0325
# step 329 | loss_acum:1.443071 | lr:  9.4089e-04 | norm: 1.0426
# step 330 | loss_acum:1.383293 | lr:  9.4053e-04 | norm: 1.0291
# step 331 | loss_acum:1.457140 | lr:  9.4018e-04 | norm: 1.1377
# step 332 | loss_acum:1.441432 | lr:  9.3983e-04 | norm: 1.0844
# step 333 | loss_acum:1.486829 | lr:  9.3948e-04 | norm: 1.2274
# step 334 | loss_acum:1.471893 | lr:  9.3912e-04 | norm: 1.0973
# step 335 | loss_acum:1.429306 | lr:  9.3877e-04 | norm: 1.1938
# step 336 | loss_acum:1.417379 | lr:  9.3841e-04 | norm: 1.0716
# step 337 | loss_acum:1.513479 | lr:  9.3805e-04 | norm: 1.1301
# step 338 | loss_acum:1.485626 | lr:  9.3769e-04 | norm: 1.1375
# step 339 | loss_acum:1.410928 | lr:  9.3734e-04 | norm: 1.0844
# step 340 | loss_acum:1.473354 | lr:  9.3697e-04 | norm: 1.0912
# step 341 | loss_acum:1.408748 | lr:  9.3661e-04 | norm: 1.2062
# step 342 | loss_acum:1.459856 | lr:  9.3625e-04 | norm: 1.0717
# step 343 | loss_acum:1.461336 | lr:  9.3589e-04 | norm: 1.2486
# step 344 | loss_acum:1.503448 | lr:  9.3552e-04 | norm: 1.1857
# step 345 | loss_acum:1.454908 | lr:  9.3516e-04 | norm: 1.2781
# step 346 | loss_acum:1.465472 | lr:  9.3479e-04 | norm: 1.0518
# step 347 | loss_acum:1.472050 | lr:  9.3443e-04 | norm: 1.0080
# step 348 | loss_acum:1.395727 | lr:  9.3406e-04 | norm: 0.9445
# step 349 | loss_acum:1.445868 | lr:  9.3369e-04 | norm: 1.2525
# step 350 | loss_acum:1.416256 | lr:  9.3332e-04 | norm: 1.0660
# step 351 | loss_acum:1.465008 | lr:  9.3295e-04 | norm: 1.2379
# step 352 | loss_acum:1.455974 | lr:  9.3258e-04 | norm: 1.1018
# step 353 | loss_acum:1.495561 | lr:  9.3220e-04 | norm: 0.9720
# step 354 | loss_acum:1.417300 | lr:  9.3183e-04 | norm: 1.0576
# step 355 | loss_acum:1.445846 | lr:  9.3146e-04 | norm: 1.0503
# step 356 | loss_acum:1.461184 | lr:  9.3108e-04 | norm: 0.9913
# step 357 | loss_acum:1.516936 | lr:  9.3070e-04 | norm: 1.2266
# step 358 | loss_acum:1.468495 | lr:  9.3033e-04 | norm: 1.0911
# step 359 | loss_acum:1.440101 | lr:  9.2995e-04 | norm: 1.1051
# step 360 | loss_acum:1.432037 | lr:  9.2957e-04 | norm: 1.0796
# step 361 | loss_acum:1.491265 | lr:  9.2919e-04 | norm: 1.2771
# step 362 | loss_acum:1.441895 | lr:  9.2881e-04 | norm: 1.2142
# step 363 | loss_acum:1.459792 | lr:  9.2843e-04 | norm: 1.2223
# step 364 | loss_acum:1.448060 | lr:  9.2804e-04 | norm: 1.2311
# step 365 | loss_acum:1.428044 | lr:  9.2766e-04 | norm: 1.1846
# step 366 | loss_acum:1.461362 | lr:  9.2727e-04 | norm: 1.1516
# step 367 | loss_acum:1.494214 | lr:  9.2689e-04 | norm: 1.2181
# step 368 | loss_acum:1.414925 | lr:  9.2650e-04 | norm: 1.2727
# step 369 | loss_acum:1.449385 | lr:  9.2611e-04 | norm: 1.0091
# step 370 | loss_acum:1.440253 | lr:  9.2573e-04 | norm: 1.1052
# step 371 | loss_acum:1.430664 | lr:  9.2534e-04 | norm: 1.1203
# step 372 | loss_acum:1.476309 | lr:  9.2495e-04 | norm: 1.0364
# step 373 | loss_acum:1.422057 | lr:  9.2455e-04 | norm: 1.0346
# step 374 | loss_acum:1.457202 | lr:  9.2416e-04 | norm: 1.0120
# step 375 | loss_acum:1.461738 | lr:  9.2377e-04 | norm: 1.0187
# step 376 | loss_acum:1.429395 | lr:  9.2338e-04 | norm: 1.2181
# step 377 | loss_acum:1.400953 | lr:  9.2298e-04 | norm: 1.1459
# step 378 | loss_acum:1.472501 | lr:  9.2258e-04 | norm: 1.1146
# step 379 | loss_acum:1.467662 | lr:  9.2219e-04 | norm: 1.0915
# step 380 | loss_acum:1.429475 | lr:  9.2179e-04 | norm: 1.0605
# step 381 | loss_acum:1.462963 | lr:  9.2139e-04 | norm: 1.0132
# step 382 | loss_acum:1.436368 | lr:  9.2099e-04 | norm: 1.1868
# step 383 | loss_acum:1.437634 | lr:  9.2059e-04 | norm: 0.9597
# step 384 | loss_acum:1.455022 | lr:  9.2019e-04 | norm: 1.0833
# step 385 | loss_acum:1.429241 | lr:  9.1979e-04 | norm: 1.0554
# step 386 | loss_acum:1.480719 | lr:  9.1938e-04 | norm: 0.9633
# step 387 | loss_acum:1.457725 | lr:  9.1898e-04 | norm: 1.2041
# step 388 | loss_acum:1.494873 | lr:  9.1857e-04 | norm: 1.1629
# step 389 | loss_acum:1.454038 | lr:  9.1817e-04 | norm: 1.0116
# step 390 | loss_acum:1.438256 | lr:  9.1776e-04 | norm: 1.0153
# step 391 | loss_acum:1.401545 | lr:  9.1735e-04 | norm: 0.9480
# step 392 | loss_acum:1.461433 | lr:  9.1695e-04 | norm: 1.0214
# step 393 | loss_acum:1.457898 | lr:  9.1654e-04 | norm: 1.0245
# step 394 | loss_acum:1.459394 | lr:  9.1612e-04 | norm: 1.0026
# step 395 | loss_acum:1.478997 | lr:  9.1571e-04 | norm: 1.0441
# step 396 | loss_acum:1.450129 | lr:  9.1530e-04 | norm: 1.0430
# step 397 | loss_acum:1.480214 | lr:  9.1489e-04 | norm: 1.0402
# step 398 | loss_acum:1.369247 | lr:  9.1447e-04 | norm: 1.1019
# step 399 | loss_acum:1.420412 | lr:  9.1406e-04 | norm: 1.0254
# step 400 | loss_acum:1.500021 | lr:  9.1364e-04 | norm: 1.2134
# us--in hath enage.
#
# CLARENCE:
# At gone--marriage:
# The and none whereing Tyferce your from and 'twereds,
# One yethour hastes hath nour spear,
# And enter a' beloming boug sides,
# Whence much art our dies so uncharge queen,
# And hath to were the daughter treasols:
# step 401 | loss_acum:1.445067 | lr:  9.1323e-04 | norm: 1.0152
# step 402 | loss_acum:1.511232 | lr:  9.1281e-04 | norm: 1.1549
# step 403 | loss_acum:1.401854 | lr:  9.1239e-04 | norm: 1.0836
# step 404 | loss_acum:1.450583 | lr:  9.1197e-04 | norm: 1.1164
# step 405 | loss_acum:1.390455 | lr:  9.1155e-04 | norm: 1.0709
# step 406 | loss_acum:1.390855 | lr:  9.1113e-04 | norm: 1.0320
# step 407 | loss_acum:1.406611 | lr:  9.1071e-04 | norm: 1.0519
# step 408 | loss_acum:1.416641 | lr:  9.1028e-04 | norm: 1.0540
# step 409 | loss_acum:1.495152 | lr:  9.0986e-04 | norm: 1.1914
# step 410 | loss_acum:1.420311 | lr:  9.0943e-04 | norm: 1.2723
# step 411 | loss_acum:1.440627 | lr:  9.0901e-04 | norm: 1.0798
# step 412 | loss_acum:1.476750 | lr:  9.0858e-04 | norm: 1.5263
# step 413 | loss_acum:1.447283 | lr:  9.0815e-04 | norm: 1.2398
# step 414 | loss_acum:1.468070 | lr:  9.0773e-04 | norm: 1.0782
# step 415 | loss_acum:1.459502 | lr:  9.0730e-04 | norm: 1.1580
# step 416 | loss_acum:1.412389 | lr:  9.0687e-04 | norm: 1.1910
# step 417 | loss_acum:1.438617 | lr:  9.0644e-04 | norm: 1.0353
# step 418 | loss_acum:1.486597 | lr:  9.0600e-04 | norm: 1.3737
# step 419 | loss_acum:1.483881 | lr:  9.0557e-04 | norm: 1.0887
# step 420 | loss_acum:1.421190 | lr:  9.0514e-04 | norm: 1.0018
# step 421 | loss_acum:1.468166 | lr:  9.0470e-04 | norm: 1.0735
# step 422 | loss_acum:1.402726 | lr:  9.0427e-04 | norm: 1.0324
# step 423 | loss_acum:1.457280 | lr:  9.0383e-04 | norm: 1.1547
# step 424 | loss_acum:1.416639 | lr:  9.0339e-04 | norm: 1.0753
# step 425 | loss_acum:1.473523 | lr:  9.0296e-04 | norm: 1.0942
# step 426 | loss_acum:1.507628 | lr:  9.0252e-04 | norm: 1.0967
# step 427 | loss_acum:1.430538 | lr:  9.0208e-04 | norm: 1.0969
# step 428 | loss_acum:1.466408 | lr:  9.0164e-04 | norm: 1.0856
# step 429 | loss_acum:1.515683 | lr:  9.0119e-04 | norm: 1.2839
# step 430 | loss_acum:1.425553 | lr:  9.0075e-04 | norm: 1.0888
# step 431 | loss_acum:1.444556 | lr:  9.0031e-04 | norm: 1.1297
# step 432 | loss_acum:1.417017 | lr:  8.9987e-04 | norm: 0.9906
# step 433 | loss_acum:1.449200 | lr:  8.9942e-04 | norm: 1.0580
# step 434 | loss_acum:1.440906 | lr:  8.9897e-04 | norm: 0.9779
# step 435 | loss_acum:1.402041 | lr:  8.9853e-04 | norm: 0.9219
# step 436 | loss_acum:1.480265 | lr:  8.9808e-04 | norm: 1.0931
# step 437 | loss_acum:1.465784 | lr:  8.9763e-04 | norm: 1.0374
# step 438 | loss_acum:1.476283 | lr:  8.9718e-04 | norm: 1.0737
# step 439 | loss_acum:1.546060 | lr:  8.9673e-04 | norm: 1.0150
# step 440 | loss_acum:1.444918 | lr:  8.9628e-04 | norm: 0.9696
# step 441 | loss_acum:1.451056 | lr:  8.9583e-04 | norm: 1.0780
# step 442 | loss_acum:1.468739 | lr:  8.9538e-04 | norm: 1.0092
# step 443 | loss_acum:1.371487 | lr:  8.9492e-04 | norm: 0.9635
# step 444 | loss_acum:1.515024 | lr:  8.9447e-04 | norm: 1.1463
# step 445 | loss_acum:1.451399 | lr:  8.9401e-04 | norm: 0.9409
# step 446 | loss_acum:1.405407 | lr:  8.9356e-04 | norm: 1.0183
# step 447 | loss_acum:1.457455 | lr:  8.9310e-04 | norm: 1.0456
# step 448 | loss_acum:1.488751 | lr:  8.9264e-04 | norm: 1.2316
# step 449 | loss_acum:1.436286 | lr:  8.9218e-04 | norm: 1.0302
# step 450 | loss_acum:1.447924 | lr:  8.9172e-04 | norm: 1.0607
# step 451 | loss_acum:1.434818 | lr:  8.9126e-04 | norm: 1.0510
# step 452 | loss_acum:1.408386 | lr:  8.9080e-04 | norm: 1.1276
# step 453 | loss_acum:1.452498 | lr:  8.9034e-04 | norm: 1.0838
# step 454 | loss_acum:1.472109 | lr:  8.8988e-04 | norm: 1.0153
# step 455 | loss_acum:1.394912 | lr:  8.8941e-04 | norm: 1.1267
# step 456 | loss_acum:1.436533 | lr:  8.8895e-04 | norm: 1.0946
# step 457 | loss_acum:1.489895 | lr:  8.8848e-04 | norm: 0.9682
# step 458 | loss_acum:1.483129 | lr:  8.8802e-04 | norm: 1.0857
# step 459 | loss_acum:1.439624 | lr:  8.8755e-04 | norm: 1.0943
# step 460 | loss_acum:1.444228 | lr:  8.8708e-04 | norm: 1.3604
# step 461 | loss_acum:1.430373 | lr:  8.8661e-04 | norm: 1.1090
# step 462 | loss_acum:1.396930 | lr:  8.8614e-04 | norm: 1.1022
# step 463 | loss_acum:1.468841 | lr:  8.8567e-04 | norm: 1.0956
# step 464 | loss_acum:1.509993 | lr:  8.8520e-04 | norm: 1.0961
# step 465 | loss_acum:1.445114 | lr:  8.8473e-04 | norm: 1.1431
# step 466 | loss_acum:1.460216 | lr:  8.8426e-04 | norm: 1.5870
# step 467 | loss_acum:1.510707 | lr:  8.8378e-04 | norm: 1.2384
# step 468 | loss_acum:1.437964 | lr:  8.8331e-04 | norm: 1.1305
# step 469 | loss_acum:1.446353 | lr:  8.8284e-04 | norm: 1.1691
# step 470 | loss_acum:1.473960 | lr:  8.8236e-04 | norm: 1.0971
# step 471 | loss_acum:1.448832 | lr:  8.8188e-04 | norm: 1.0303
# step 472 | loss_acum:1.441715 | lr:  8.8140e-04 | norm: 1.0692
# step 473 | loss_acum:1.462532 | lr:  8.8093e-04 | norm: 1.0918
# step 474 | loss_acum:1.483958 | lr:  8.8045e-04 | norm: 1.0642
# step 475 | loss_acum:1.429214 | lr:  8.7997e-04 | norm: 1.1110
# step 476 | loss_acum:1.428962 | lr:  8.7948e-04 | norm: 1.1177
# step 477 | loss_acum:1.420356 | lr:  8.7900e-04 | norm: 1.0181
# step 478 | loss_acum:1.476857 | lr:  8.7852e-04 | norm: 1.1454
# step 479 | loss_acum:1.406327 | lr:  8.7804e-04 | norm: 1.1313
# step 480 | loss_acum:1.440519 | lr:  8.7755e-04 | norm: 1.0310
# step 481 | loss_acum:1.476571 | lr:  8.7707e-04 | norm: 1.0883
# step 482 | loss_acum:1.436296 | lr:  8.7658e-04 | norm: 1.0422
# step 483 | loss_acum:1.384304 | lr:  8.7610e-04 | norm: 1.0443
# step 484 | loss_acum:1.403537 | lr:  8.7561e-04 | norm: 1.1127
# step 485 | loss_acum:1.454937 | lr:  8.7512e-04 | norm: 1.0677
# step 486 | loss_acum:1.418138 | lr:  8.7463e-04 | norm: 1.1267
# step 487 | loss_acum:1.449433 | lr:  8.7414e-04 | norm: 1.0796
# step 488 | loss_acum:1.448829 | lr:  8.7365e-04 | norm: 0.9849
# step 489 | loss_acum:1.394293 | lr:  8.7316e-04 | norm: 1.1426
# step 490 | loss_acum:1.482772 | lr:  8.7267e-04 | norm: 1.1655
# step 491 | loss_acum:1.458528 | lr:  8.7217e-04 | norm: 1.0345
# step 492 | loss_acum:1.528923 | lr:  8.7168e-04 | norm: 1.0171
# step 493 | loss_acum:1.457532 | lr:  8.7118e-04 | norm: 1.0599
# step 494 | loss_acum:1.443185 | lr:  8.7069e-04 | norm: 1.1071
# step 495 | loss_acum:1.412835 | lr:  8.7019e-04 | norm: 1.1162
# step 496 | loss_acum:1.385397 | lr:  8.6970e-04 | norm: 1.1085
# step 497 | loss_acum:1.424333 | lr:  8.6920e-04 | norm: 0.9571
# step 498 | loss_acum:1.498528 | lr:  8.6870e-04 | norm: 1.1397
# step 499 | loss_acum:1.455510 | lr:  8.6820e-04 | norm: 1.0221
# step 500: train loss 1.4464, val loss 1.6302
# step 500 | loss_acum:1.418575 | lr:  8.6770e-04 | norm: 1.1559
# step 501 | loss_acum:1.398368 | lr:  8.6720e-04 | norm: 1.0444
# step 502 | loss_acum:1.417751 | lr:  8.6670e-04 | norm: 0.9714
# step 503 | loss_acum:1.414771 | lr:  8.6619e-04 | norm: 0.9655
# step 504 | loss_acum:1.436224 | lr:  8.6569e-04 | norm: 1.0985
# step 505 | loss_acum:1.487428 | lr:  8.6519e-04 | norm: 1.0099
# step 506 | loss_acum:1.407013 | lr:  8.6468e-04 | norm: 0.9289
# step 507 | loss_acum:1.444473 | lr:  8.6418e-04 | norm: 1.1414
# step 508 | loss_acum:1.444475 | lr:  8.6367e-04 | norm: 1.0452
# step 509 | loss_acum:1.466016 | lr:  8.6316e-04 | norm: 1.0146
# step 510 | loss_acum:1.440798 | lr:  8.6265e-04 | norm: 1.0657
# step 511 | loss_acum:1.500919 | lr:  8.6215e-04 | norm: 1.0416
# step 512 | loss_acum:1.451120 | lr:  8.6164e-04 | norm: 1.0196
# step 513 | loss_acum:1.393877 | lr:  8.6113e-04 | norm: 0.9548
# step 514 | loss_acum:1.437509 | lr:  8.6061e-04 | norm: 0.9947
# step 515 | loss_acum:1.394854 | lr:  8.6010e-04 | norm: 1.0769
# step 516 | loss_acum:1.437091 | lr:  8.5959e-04 | norm: 1.0439
# step 517 | loss_acum:1.437212 | lr:  8.5908e-04 | norm: 1.1908
# step 518 | loss_acum:1.457819 | lr:  8.5856e-04 | norm: 1.1077
# step 519 | loss_acum:1.429785 | lr:  8.5805e-04 | norm: 1.2646
# step 520 | loss_acum:1.423533 | lr:  8.5753e-04 | norm: 1.1141
# step 521 | loss_acum:1.481283 | lr:  8.5702e-04 | norm: 1.1649
# step 522 | loss_acum:1.450452 | lr:  8.5650e-04 | norm: 1.0820
# step 523 | loss_acum:1.466089 | lr:  8.5598e-04 | norm: 1.1107
# step 524 | loss_acum:1.365221 | lr:  8.5546e-04 | norm: 0.9674
# step 525 | loss_acum:1.458257 | lr:  8.5494e-04 | norm: 1.0179
# step 526 | loss_acum:1.390542 | lr:  8.5442e-04 | norm: 1.0640
# step 527 | loss_acum:1.429054 | lr:  8.5390e-04 | norm: 1.1408
# step 528 | loss_acum:1.381256 | lr:  8.5338e-04 | norm: 0.9643
# step 529 | loss_acum:1.448763 | lr:  8.5286e-04 | norm: 0.9952
# step 530 | loss_acum:1.363330 | lr:  8.5233e-04 | norm: 0.9282
# step 531 | loss_acum:1.423148 | lr:  8.5181e-04 | norm: 1.0483
# step 532 | loss_acum:1.449344 | lr:  8.5128e-04 | norm: 1.0107
# step 533 | loss_acum:1.387667 | lr:  8.5076e-04 | norm: 1.0436
# step 534 | loss_acum:1.473137 | lr:  8.5023e-04 | norm: 0.9481
# step 535 | loss_acum:1.454606 | lr:  8.4971e-04 | norm: 1.1256
# step 536 | loss_acum:1.438164 | lr:  8.4918e-04 | norm: 1.2077
# step 537 | loss_acum:1.448315 | lr:  8.4865e-04 | norm: 1.1331
# step 538 | loss_acum:1.457791 | lr:  8.4812e-04 | norm: 1.2531
# step 539 | loss_acum:1.400220 | lr:  8.4759e-04 | norm: 1.0758
# step 540 | loss_acum:1.482651 | lr:  8.4706e-04 | norm: 1.1325
# step 541 | loss_acum:1.475908 | lr:  8.4653e-04 | norm: 1.1709
# step 542 | loss_acum:1.408914 | lr:  8.4600e-04 | norm: 1.0346
# step 543 | loss_acum:1.407513 | lr:  8.4546e-04 | norm: 0.9403
# step 544 | loss_acum:1.423791 | lr:  8.4493e-04 | norm: 1.0574
# step 545 | loss_acum:1.446858 | lr:  8.4440e-04 | norm: 1.0399
# step 546 | loss_acum:1.465373 | lr:  8.4386e-04 | norm: 1.0149
# step 547 | loss_acum:1.478496 | lr:  8.4333e-04 | norm: 1.0336
# step 548 | loss_acum:1.453226 | lr:  8.4279e-04 | norm: 1.0169
# step 549 | loss_acum:1.412918 | lr:  8.4225e-04 | norm: 1.0583
# step 550 | loss_acum:1.447982 | lr:  8.4171e-04 | norm: 1.0346
# step 551 | loss_acum:1.422310 | lr:  8.4118e-04 | norm: 1.1266
# step 552 | loss_acum:1.458512 | lr:  8.4064e-04 | norm: 1.0709
# step 553 | loss_acum:1.408520 | lr:  8.4010e-04 | norm: 0.9942
# step 554 | loss_acum:1.411976 | lr:  8.3956e-04 | norm: 1.0825
# step 555 | loss_acum:1.432198 | lr:  8.3901e-04 | norm: 1.0942
# step 556 | loss_acum:1.407595 | lr:  8.3847e-04 | norm: 1.0520
# step 557 | loss_acum:1.416097 | lr:  8.3793e-04 | norm: 1.0388
# step 558 | loss_acum:1.417913 | lr:  8.3739e-04 | norm: 1.0360
# step 559 | loss_acum:1.409892 | lr:  8.3684e-04 | norm: 1.0221
# step 560 | loss_acum:1.455875 | lr:  8.3630e-04 | norm: 1.1011
# step 561 | loss_acum:1.484559 | lr:  8.3575e-04 | norm: 1.0556
# step 562 | loss_acum:1.444127 | lr:  8.3520e-04 | norm: 1.0559
# step 563 | loss_acum:1.407164 | lr:  8.3466e-04 | norm: 1.0605
# step 564 | loss_acum:1.500909 | lr:  8.3411e-04 | norm: 0.9840
# step 565 | loss_acum:1.412178 | lr:  8.3356e-04 | norm: 1.0476
# step 566 | loss_acum:1.448206 | lr:  8.3301e-04 | norm: 1.0949
# step 567 | loss_acum:1.439082 | lr:  8.3246e-04 | norm: 1.0197
# step 568 | loss_acum:1.444991 | lr:  8.3191e-04 | norm: 1.0537
# step 569 | loss_acum:1.430172 | lr:  8.3136e-04 | norm: 1.1383
# step 570 | loss_acum:1.428303 | lr:  8.3081e-04 | norm: 1.0795
# step 571 | loss_acum:1.416132 | lr:  8.3026e-04 | norm: 1.0460
# step 572 | loss_acum:1.461814 | lr:  8.2970e-04 | norm: 1.1158
# step 573 | loss_acum:1.467794 | lr:  8.2915e-04 | norm: 1.0001
# step 574 | loss_acum:1.406904 | lr:  8.2859e-04 | norm: 0.9668
# step 575 | loss_acum:1.429824 | lr:  8.2804e-04 | norm: 1.1308
# step 576 | loss_acum:1.404189 | lr:  8.2748e-04 | norm: 1.0377
# step 577 | loss_acum:1.466010 | lr:  8.2692e-04 | norm: 1.1872
# step 578 | loss_acum:1.436330 | lr:  8.2637e-04 | norm: 1.1536
# step 579 | loss_acum:1.412837 | lr:  8.2581e-04 | norm: 1.1170
# step 580 | loss_acum:1.525591 | lr:  8.2525e-04 | norm: 1.0828
# step 581 | loss_acum:1.465931 | lr:  8.2469e-04 | norm: 1.0977
# step 582 | loss_acum:1.420647 | lr:  8.2413e-04 | norm: 1.1034
# step 583 | loss_acum:1.500963 | lr:  8.2357e-04 | norm: 1.1404
# step 584 | loss_acum:1.381483 | lr:  8.2301e-04 | norm: 1.0063
# step 585 | loss_acum:1.457547 | lr:  8.2245e-04 | norm: 1.1167
# step 586 | loss_acum:1.351655 | lr:  8.2188e-04 | norm: 1.2267
# step 587 | loss_acum:1.413185 | lr:  8.2132e-04 | norm: 1.0186
# step 588 | loss_acum:1.391128 | lr:  8.2076e-04 | norm: 0.8891
# step 589 | loss_acum:1.482526 | lr:  8.2019e-04 | norm: 1.1537
# step 590 | loss_acum:1.422628 | lr:  8.1962e-04 | norm: 0.9580
# step 591 | loss_acum:1.388356 | lr:  8.1906e-04 | norm: 0.9218
# step 592 | loss_acum:1.433009 | lr:  8.1849e-04 | norm: 1.1230
# step 593 | loss_acum:1.408636 | lr:  8.1792e-04 | norm: 1.0051
# step 594 | loss_acum:1.411600 | lr:  8.1736e-04 | norm: 1.0760
# step 595 | loss_acum:1.436604 | lr:  8.1679e-04 | norm: 0.9355
# step 596 | loss_acum:1.351968 | lr:  8.1622e-04 | norm: 1.0183
# step 597 | loss_acum:1.385450 | lr:  8.1565e-04 | norm: 1.0040
# step 598 | loss_acum:1.343209 | lr:  8.1508e-04 | norm: 0.9533
# step 599 | loss_acum:1.490713 | lr:  8.1450e-04 | norm: 1.1901
# step 600 | loss_acum:1.379481 | lr:  8.1393e-04 | norm: 1.1827
#  king, weak a mother right priencess he heavy and pleason:
# Toow bear calle he many he racces been blood,
# To make under lastice 'Monten' in for his made
# I heart toe must the art and the should 'tis fown,
# And no fayer-moveric, ond fault with my friaist,
# My un
# step 601 | loss_acum:1.366884 | lr:  8.1336e-04 | norm: 0.9945
# step 602 | loss_acum:1.434615 | lr:  8.1279e-04 | norm: 1.0794
# step 603 | loss_acum:1.503057 | lr:  8.1221e-04 | norm: 1.0543
# step 604 | loss_acum:1.385024 | lr:  8.1164e-04 | norm: 1.0730
# step 605 | loss_acum:1.329557 | lr:  8.1106e-04 | norm: 1.0733
# step 606 | loss_acum:1.448850 | lr:  8.1049e-04 | norm: 0.9887
# step 607 | loss_acum:1.434690 | lr:  8.0991e-04 | norm: 1.1460
# step 608 | loss_acum:1.428353 | lr:  8.0933e-04 | norm: 1.0083
# step 609 | loss_acum:1.441629 | lr:  8.0875e-04 | norm: 1.0668
# step 610 | loss_acum:1.455014 | lr:  8.0817e-04 | norm: 1.1169
# step 611 | loss_acum:1.376906 | lr:  8.0760e-04 | norm: 0.9478
# step 612 | loss_acum:1.399702 | lr:  8.0702e-04 | norm: 0.9653
# step 613 | loss_acum:1.454899 | lr:  8.0644e-04 | norm: 1.0748
# step 614 | loss_acum:1.424938 | lr:  8.0585e-04 | norm: 1.0809
# step 615 | loss_acum:1.449006 | lr:  8.0527e-04 | norm: 1.0512
# step 616 | loss_acum:1.367878 | lr:  8.0469e-04 | norm: 1.0716
# step 617 | loss_acum:1.458441 | lr:  8.0411e-04 | norm: 0.9938
# step 618 | loss_acum:1.410094 | lr:  8.0352e-04 | norm: 1.0641
# step 619 | loss_acum:1.425652 | lr:  8.0294e-04 | norm: 1.0940
# step 620 | loss_acum:1.402653 | lr:  8.0235e-04 | norm: 1.1004
# step 621 | loss_acum:1.362534 | lr:  8.0177e-04 | norm: 0.9069
# step 622 | loss_acum:1.456098 | lr:  8.0118e-04 | norm: 1.0973
# step 623 | loss_acum:1.483683 | lr:  8.0060e-04 | norm: 1.1012
# step 624 | loss_acum:1.416266 | lr:  8.0001e-04 | norm: 1.0531
# step 625 | loss_acum:1.412615 | lr:  7.9942e-04 | norm: 1.0232
# step 626 | loss_acum:1.466960 | lr:  7.9883e-04 | norm: 1.1902
# step 627 | loss_acum:1.423058 | lr:  7.9824e-04 | norm: 1.0803
# step 628 | loss_acum:1.434585 | lr:  7.9765e-04 | norm: 1.1011
# step 629 | loss_acum:1.478846 | lr:  7.9706e-04 | norm: 1.1515
# step 630 | loss_acum:1.400160 | lr:  7.9647e-04 | norm: 0.9927
# step 631 | loss_acum:1.462210 | lr:  7.9588e-04 | norm: 1.0051
# step 632 | loss_acum:1.417065 | lr:  7.9529e-04 | norm: 0.9636
# step 633 | loss_acum:1.441556 | lr:  7.9469e-04 | norm: 1.0634
# step 634 | loss_acum:1.458811 | lr:  7.9410e-04 | norm: 1.0882
# step 635 | loss_acum:1.443687 | lr:  7.9351e-04 | norm: 1.1926
# step 636 | loss_acum:1.418728 | lr:  7.9291e-04 | norm: 0.9688
# step 637 | loss_acum:1.384806 | lr:  7.9232e-04 | norm: 1.0490
# step 638 | loss_acum:1.402345 | lr:  7.9172e-04 | norm: 1.0181
# step 639 | loss_acum:1.468117 | lr:  7.9112e-04 | norm: 1.0132
# step 640 | loss_acum:1.452468 | lr:  7.9053e-04 | norm: 1.1994
# step 641 | loss_acum:1.465313 | lr:  7.8993e-04 | norm: 1.1251
# step 642 | loss_acum:1.414365 | lr:  7.8933e-04 | norm: 1.0400
# step 643 | loss_acum:1.380050 | lr:  7.8873e-04 | norm: 1.1424
# step 644 | loss_acum:1.463093 | lr:  7.8813e-04 | norm: 1.1065
# step 645 | loss_acum:1.403675 | lr:  7.8753e-04 | norm: 0.9661
# step 646 | loss_acum:1.415266 | lr:  7.8693e-04 | norm: 1.0792
# step 647 | loss_acum:1.473351 | lr:  7.8633e-04 | norm: 1.1288
# step 648 | loss_acum:1.404431 | lr:  7.8573e-04 | norm: 1.1611
# step 649 | loss_acum:1.427105 | lr:  7.8513e-04 | norm: 1.0819
# step 650 | loss_acum:1.492562 | lr:  7.8452e-04 | norm: 1.0755
# step 651 | loss_acum:1.543613 | lr:  7.8392e-04 | norm: 1.1571
# step 652 | loss_acum:1.376768 | lr:  7.8331e-04 | norm: 1.0184
# step 653 | loss_acum:1.387028 | lr:  7.8271e-04 | norm: 1.2439
# step 654 | loss_acum:1.482761 | lr:  7.8210e-04 | norm: 1.2383
# step 655 | loss_acum:1.422411 | lr:  7.8150e-04 | norm: 0.9772
# step 656 | loss_acum:1.487017 | lr:  7.8089e-04 | norm: 1.2731
# step 657 | loss_acum:1.452658 | lr:  7.8029e-04 | norm: 1.1148
# step 658 | loss_acum:1.463419 | lr:  7.7968e-04 | norm: 1.1768
# step 659 | loss_acum:1.472764 | lr:  7.7907e-04 | norm: 1.1401
# step 660 | loss_acum:1.368645 | lr:  7.7846e-04 | norm: 1.0042
# step 661 | loss_acum:1.428672 | lr:  7.7785e-04 | norm: 1.0071
# step 662 | loss_acum:1.406827 | lr:  7.7724e-04 | norm: 1.0470
# step 663 | loss_acum:1.497919 | lr:  7.7663e-04 | norm: 1.0272
# step 664 | loss_acum:1.472767 | lr:  7.7602e-04 | norm: 1.3199
# step 665 | loss_acum:1.423167 | lr:  7.7541e-04 | norm: 1.0552
# step 666 | loss_acum:1.479780 | lr:  7.7480e-04 | norm: 1.0229
# step 667 | loss_acum:1.461428 | lr:  7.7418e-04 | norm: 1.0681
# step 668 | loss_acum:1.422677 | lr:  7.7357e-04 | norm: 1.0511
# step 669 | loss_acum:1.347411 | lr:  7.7296e-04 | norm: 1.0719
# step 670 | loss_acum:1.428679 | lr:  7.7234e-04 | norm: 1.0255
# step 671 | loss_acum:1.402884 | lr:  7.7173e-04 | norm: 0.9677
# step 672 | loss_acum:1.418757 | lr:  7.7111e-04 | norm: 0.9511
# step 673 | loss_acum:1.445912 | lr:  7.7050e-04 | norm: 1.0538
# step 674 | loss_acum:1.358534 | lr:  7.6988e-04 | norm: 0.9163
# step 675 | loss_acum:1.421971 | lr:  7.6926e-04 | norm: 0.9813
# step 676 | loss_acum:1.468703 | lr:  7.6865e-04 | norm: 0.9494
# step 677 | loss_acum:1.405981 | lr:  7.6803e-04 | norm: 0.9704
# step 678 | loss_acum:1.446330 | lr:  7.6741e-04 | norm: 1.0533
# step 679 | loss_acum:1.421072 | lr:  7.6679e-04 | norm: 1.0058
# step 680 | loss_acum:1.468059 | lr:  7.6617e-04 | norm: 0.9878
# step 681 | loss_acum:1.411032 | lr:  7.6555e-04 | norm: 1.0583
# step 682 | loss_acum:1.418941 | lr:  7.6493e-04 | norm: 1.0266
# step 683 | loss_acum:1.441128 | lr:  7.6431e-04 | norm: 1.1468
# step 684 | loss_acum:1.383229 | lr:  7.6369e-04 | norm: 0.9857
# step 685 | loss_acum:1.407967 | lr:  7.6306e-04 | norm: 1.0240
# step 686 | loss_acum:1.431903 | lr:  7.6244e-04 | norm: 0.9248
# step 687 | loss_acum:1.416728 | lr:  7.6182e-04 | norm: 1.0075
# step 688 | loss_acum:1.427584 | lr:  7.6119e-04 | norm: 1.0296
# step 689 | loss_acum:1.469079 | lr:  7.6057e-04 | norm: 1.0207
# step 690 | loss_acum:1.451056 | lr:  7.5994e-04 | norm: 1.0738
# step 691 | loss_acum:1.437562 | lr:  7.5932e-04 | norm: 0.9644
# step 692 | loss_acum:1.443861 | lr:  7.5869e-04 | norm: 1.0073
# step 693 | loss_acum:1.419801 | lr:  7.5807e-04 | norm: 0.9514
# step 694 | loss_acum:1.425895 | lr:  7.5744e-04 | norm: 1.0065
# step 695 | loss_acum:1.466467 | lr:  7.5681e-04 | norm: 0.9471
# step 696 | loss_acum:1.473110 | lr:  7.5618e-04 | norm: 1.1139
# step 697 | loss_acum:1.434706 | lr:  7.5556e-04 | norm: 1.0294
# step 698 | loss_acum:1.390066 | lr:  7.5493e-04 | norm: 0.9892
# step 699 | loss_acum:1.479203 | lr:  7.5430e-04 | norm: 1.0784
# step 700 | loss_acum:1.413731 | lr:  7.5367e-04 | norm: 1.0738
# step 701 | loss_acum:1.477417 | lr:  7.5304e-04 | norm: 1.1537
# step 702 | loss_acum:1.421722 | lr:  7.5241e-04 | norm: 1.2645
# step 703 | loss_acum:1.484824 | lr:  7.5177e-04 | norm: 1.1367
# step 704 | loss_acum:1.431059 | lr:  7.5114e-04 | norm: 0.9424
# step 705 | loss_acum:1.394545 | lr:  7.5051e-04 | norm: 1.2178
# step 706 | loss_acum:1.424547 | lr:  7.4988e-04 | norm: 1.1323
# step 707 | loss_acum:1.454194 | lr:  7.4924e-04 | norm: 0.9189
# step 708 | loss_acum:1.368137 | lr:  7.4861e-04 | norm: 0.8774
# step 709 | loss_acum:1.481064 | lr:  7.4797e-04 | norm: 1.0958
# step 710 | loss_acum:1.416788 | lr:  7.4734e-04 | norm: 1.0606
# step 711 | loss_acum:1.423250 | lr:  7.4670e-04 | norm: 1.1132
# step 712 | loss_acum:1.389808 | lr:  7.4607e-04 | norm: 1.1660
# step 713 | loss_acum:1.420153 | lr:  7.4543e-04 | norm: 1.1161
# step 714 | loss_acum:1.443133 | lr:  7.4479e-04 | norm: 1.0371
# step 715 | loss_acum:1.370843 | lr:  7.4416e-04 | norm: 1.0065
# step 716 | loss_acum:1.468877 | lr:  7.4352e-04 | norm: 1.0699
# step 717 | loss_acum:1.439901 | lr:  7.4288e-04 | norm: 1.0972
# step 718 | loss_acum:1.406619 | lr:  7.4224e-04 | norm: 1.0232
# step 719 | loss_acum:1.410398 | lr:  7.4160e-04 | norm: 1.2414
# step 720 | loss_acum:1.477139 | lr:  7.4096e-04 | norm: 0.9854
# step 721 | loss_acum:1.396483 | lr:  7.4032e-04 | norm: 0.9896
# step 722 | loss_acum:1.493329 | lr:  7.3968e-04 | norm: 1.0302
# step 723 | loss_acum:1.381801 | lr:  7.3904e-04 | norm: 0.9744
# step 724 | loss_acum:1.380485 | lr:  7.3840e-04 | norm: 0.9667
# step 725 | loss_acum:1.485459 | lr:  7.3776e-04 | norm: 0.9728
# step 726 | loss_acum:1.413188 | lr:  7.3711e-04 | norm: 1.0750
# step 727 | loss_acum:1.407741 | lr:  7.3647e-04 | norm: 0.9378
# step 728 | loss_acum:1.417597 | lr:  7.3583e-04 | norm: 1.0847
# step 729 | loss_acum:1.441539 | lr:  7.3518e-04 | norm: 0.9932
# step 730 | loss_acum:1.418585 | lr:  7.3454e-04 | norm: 0.9258
# step 731 | loss_acum:1.473357 | lr:  7.3389e-04 | norm: 1.1106
# step 732 | loss_acum:1.486081 | lr:  7.3325e-04 | norm: 1.0994
# step 733 | loss_acum:1.471849 | lr:  7.3260e-04 | norm: 1.0357
# step 734 | loss_acum:1.434572 | lr:  7.3196e-04 | norm: 1.0728
# step 735 | loss_acum:1.451871 | lr:  7.3131e-04 | norm: 1.0920
# step 736 | loss_acum:1.423635 | lr:  7.3066e-04 | norm: 0.9976
# step 737 | loss_acum:1.466458 | lr:  7.3001e-04 | norm: 1.0600
# step 738 | loss_acum:1.428417 | lr:  7.2937e-04 | norm: 1.0039
# step 739 | loss_acum:1.384311 | lr:  7.2872e-04 | norm: 1.1616
# step 740 | loss_acum:1.391080 | lr:  7.2807e-04 | norm: 0.9616
# step 741 | loss_acum:1.420983 | lr:  7.2742e-04 | norm: 1.0438
# step 742 | loss_acum:1.446156 | lr:  7.2677e-04 | norm: 0.9671
# step 743 | loss_acum:1.427538 | lr:  7.2612e-04 | norm: 0.9776
# step 744 | loss_acum:1.422825 | lr:  7.2547e-04 | norm: 1.0586
# ...
# step 1755 | loss_acum:1.243844 | lr:  1.3265e-04 | norm: 0.9583
# step 1756 | loss_acum:1.281759 | lr:  1.3239e-04 | norm: 0.8783
# step 1757 | loss_acum:1.395964 | lr:  1.3212e-04 | norm: 0.9881
# step 1758 | loss_acum:1.296109 | lr:  1.3186e-04 | norm: 0.9528
# step 1759 | loss_acum:1.249462 | lr:  1.3160e-04 | norm: 0.9178
# step 1760 | loss_acum:1.332448 | lr:  1.3134e-04 | norm: 0.9037
# step 1761 | loss_acum:1.311667 | lr:  1.3108e-04 | norm: 1.0173
# step 1762 | loss_acum:1.316052 | lr:  1.3083e-04 | norm: 0.9691
# step 1763 | loss_acum:1.281141 | lr:  1.3057e-04 | norm: 1.0030
# step 1764 | loss_acum:1.298089 | lr:  1.3031e-04 | norm: 0.9668
# step 1765 | loss_acum:1.314285 | lr:  1.3006e-04 | norm: 0.9468
# step 1766 | loss_acum:1.285168 | lr:  1.2981e-04 | norm: 0.8744
# step 1767 | loss_acum:1.339890 | lr:  1.2955e-04 | norm: 0.9020
# step 1768 | loss_acum:1.293505 | lr:  1.2930e-04 | norm: 0.8843
# step 1769 | loss_acum:1.328594 | lr:  1.2905e-04 | norm: 1.0288
# step 1770 | loss_acum:1.372375 | lr:  1.2880e-04 | norm: 0.9546
# step 1771 | loss_acum:1.309648 | lr:  1.2855e-04 | norm: 0.9315
# step 1772 | loss_acum:1.294608 | lr:  1.2831e-04 | norm: 0.8711
# step 1773 | loss_acum:1.282270 | lr:  1.2806e-04 | norm: 0.9085
# step 1774 | loss_acum:1.354121 | lr:  1.2781e-04 | norm: 0.9851
# step 1775 | loss_acum:1.313955 | lr:  1.2757e-04 | norm: 0.9373
# step 1776 | loss_acum:1.300026 | lr:  1.2733e-04 | norm: 0.9048
# step 1777 | loss_acum:1.263333 | lr:  1.2709e-04 | norm: 0.8742
# step 1778 | loss_acum:1.227317 | lr:  1.2684e-04 | norm: 0.8992
# step 1779 | loss_acum:1.320874 | lr:  1.2660e-04 | norm: 0.9728
# step 1780 | loss_acum:1.299152 | lr:  1.2637e-04 | norm: 0.9469
# step 1781 | loss_acum:1.257275 | lr:  1.2613e-04 | norm: 0.9249
# step 1782 | loss_acum:1.338418 | lr:  1.2589e-04 | norm: 0.9676
# step 1783 | loss_acum:1.260912 | lr:  1.2566e-04 | norm: 0.9256
# step 1784 | loss_acum:1.358990 | lr:  1.2542e-04 | norm: 0.9299
# step 1785 | loss_acum:1.312309 | lr:  1.2519e-04 | norm: 0.9837
# step 1786 | loss_acum:1.317490 | lr:  1.2495e-04 | norm: 0.9219
# step 1787 | loss_acum:1.324695 | lr:  1.2472e-04 | norm: 0.9580
# step 1788 | loss_acum:1.330751 | lr:  1.2449e-04 | norm: 0.9702
# step 1789 | loss_acum:1.264399 | lr:  1.2426e-04 | norm: 0.9261
# step 1790 | loss_acum:1.348964 | lr:  1.2403e-04 | norm: 1.0639
# step 1791 | loss_acum:1.309285 | lr:  1.2381e-04 | norm: 0.9292
# step 1792 | loss_acum:1.316419 | lr:  1.2358e-04 | norm: 0.9512
# step 1793 | loss_acum:1.322606 | lr:  1.2336e-04 | norm: 0.9723
# step 1794 | loss_acum:1.314843 | lr:  1.2313e-04 | norm: 0.9476
# step 1795 | loss_acum:1.364188 | lr:  1.2291e-04 | norm: 0.9189
# step 1796 | loss_acum:1.287808 | lr:  1.2269e-04 | norm: 1.0097
# step 1797 | loss_acum:1.360977 | lr:  1.2246e-04 | norm: 1.0535
# step 1798 | loss_acum:1.393319 | lr:  1.2224e-04 | norm: 1.0086
# step 1799 | loss_acum:1.324250 | lr:  1.2203e-04 | norm: 1.0058
# step 1800 | loss_acum:1.311806 | lr:  1.2181e-04 | norm: 0.8891
#  VINGA:
# Warwick work, these denather by your nobly:
# My lord, by all Richmond? Do to Shoron's mine!
# How! cannot I have not prince his on
# Mad-goess, keigne now me to quick o'er your consul.
#
# RICHARD:
# I am not own: Bla-hold, to the further well,
# That come of j
# step 1801 | loss_acum:1.290114 | lr:  1.2159e-04 | norm: 0.8977
# step 1802 | loss_acum:1.265910 | lr:  1.2138e-04 | norm: 0.9510
# step 1803 | loss_acum:1.372186 | lr:  1.2116e-04 | norm: 1.0341
# step 1804 | loss_acum:1.309168 | lr:  1.2095e-04 | norm: 0.9565
# step 1805 | loss_acum:1.273839 | lr:  1.2073e-04 | norm: 0.8890
# step 1806 | loss_acum:1.314811 | lr:  1.2052e-04 | norm: 0.9463
# step 1807 | loss_acum:1.293862 | lr:  1.2031e-04 | norm: 0.9422
# step 1808 | loss_acum:1.293844 | lr:  1.2010e-04 | norm: 0.9320
# step 1809 | loss_acum:1.348237 | lr:  1.1989e-04 | norm: 0.9840
# step 1810 | loss_acum:1.296184 | lr:  1.1969e-04 | norm: 0.9744
# step 1811 | loss_acum:1.363515 | lr:  1.1948e-04 | norm: 0.9570
# step 1812 | loss_acum:1.284020 | lr:  1.1928e-04 | norm: 0.9311
# step 1813 | loss_acum:1.304033 | lr:  1.1907e-04 | norm: 1.0139
# step 1814 | loss_acum:1.311682 | lr:  1.1887e-04 | norm: 1.0077
# step 1815 | loss_acum:1.278280 | lr:  1.1867e-04 | norm: 0.9921
# step 1816 | loss_acum:1.307985 | lr:  1.1847e-04 | norm: 0.9354
# step 1817 | loss_acum:1.290674 | lr:  1.1827e-04 | norm: 0.8926
# step 1818 | loss_acum:1.327035 | lr:  1.1807e-04 | norm: 0.9110
# step 1819 | loss_acum:1.308608 | lr:  1.1787e-04 | norm: 0.9434
# step 1820 | loss_acum:1.330441 | lr:  1.1767e-04 | norm: 0.9580
# step 1821 | loss_acum:1.311173 | lr:  1.1748e-04 | norm: 0.9435
# step 1822 | loss_acum:1.342637 | lr:  1.1728e-04 | norm: 0.9776
# step 1823 | loss_acum:1.370670 | lr:  1.1709e-04 | norm: 0.9551
# step 1824 | loss_acum:1.267711 | lr:  1.1690e-04 | norm: 1.0011
# step 1825 | loss_acum:1.255416 | lr:  1.1670e-04 | norm: 0.9674
# step 1826 | loss_acum:1.266576 | lr:  1.1651e-04 | norm: 0.9131
# step 1827 | loss_acum:1.322089 | lr:  1.1633e-04 | norm: 0.9229
# step 1828 | loss_acum:1.337403 | lr:  1.1614e-04 | norm: 0.9963
# step 1829 | loss_acum:1.315182 | lr:  1.1595e-04 | norm: 0.9974
# step 1830 | loss_acum:1.321864 | lr:  1.1576e-04 | norm: 0.9560
# step 1831 | loss_acum:1.308459 | lr:  1.1558e-04 | norm: 0.9709
# step 1832 | loss_acum:1.228559 | lr:  1.1540e-04 | norm: 0.9132
# step 1833 | loss_acum:1.333665 | lr:  1.1521e-04 | norm: 1.0220
# step 1834 | loss_acum:1.320605 | lr:  1.1503e-04 | norm: 0.9936
# step 1835 | loss_acum:1.282066 | lr:  1.1485e-04 | norm: 0.9134
# step 1836 | loss_acum:1.305100 | lr:  1.1467e-04 | norm: 0.9391
# step 1837 | loss_acum:1.322273 | lr:  1.1449e-04 | norm: 0.9280
# step 1838 | loss_acum:1.302091 | lr:  1.1432e-04 | norm: 0.9414
# step 1839 | loss_acum:1.290880 | lr:  1.1414e-04 | norm: 1.0368
# step 1840 | loss_acum:1.298289 | lr:  1.1396e-04 | norm: 1.0287
# step 1841 | loss_acum:1.277911 | lr:  1.1379e-04 | norm: 0.9332
# step 1842 | loss_acum:1.304751 | lr:  1.1362e-04 | norm: 0.9218
# step 1843 | loss_acum:1.320071 | lr:  1.1344e-04 | norm: 0.9937
# step 1844 | loss_acum:1.319809 | lr:  1.1327e-04 | norm: 0.9363
# step 1845 | loss_acum:1.303230 | lr:  1.1310e-04 | norm: 0.9426
# step 1846 | loss_acum:1.322246 | lr:  1.1293e-04 | norm: 0.9377
# step 1847 | loss_acum:1.262311 | lr:  1.1277e-04 | norm: 0.8832
# step 1848 | loss_acum:1.333494 | lr:  1.1260e-04 | norm: 1.0313
# step 1849 | loss_acum:1.305277 | lr:  1.1243e-04 | norm: 1.0043
# step 1850 | loss_acum:1.320127 | lr:  1.1227e-04 | norm: 0.9183
# step 1851 | loss_acum:1.288998 | lr:  1.1211e-04 | norm: 0.9614
# step 1852 | loss_acum:1.314543 | lr:  1.1194e-04 | norm: 1.0046
# step 1853 | loss_acum:1.270702 | lr:  1.1178e-04 | norm: 0.9125
# step 1854 | loss_acum:1.285806 | lr:  1.1162e-04 | norm: 0.9641
# step 1855 | loss_acum:1.264909 | lr:  1.1146e-04 | norm: 1.0298
# step 1856 | loss_acum:1.302822 | lr:  1.1131e-04 | norm: 0.9319
# step 1857 | loss_acum:1.311590 | lr:  1.1115e-04 | norm: 1.0756
# step 1858 | loss_acum:1.307942 | lr:  1.1099e-04 | norm: 0.9772
# step 1859 | loss_acum:1.331652 | lr:  1.1084e-04 | norm: 1.0166
# step 1860 | loss_acum:1.273355 | lr:  1.1068e-04 | norm: 0.9567
# step 1861 | loss_acum:1.233510 | lr:  1.1053e-04 | norm: 0.9138
# step 1862 | loss_acum:1.295746 | lr:  1.1038e-04 | norm: 0.9314
# step 1863 | loss_acum:1.238562 | lr:  1.1023e-04 | norm: 0.9129
# step 1864 | loss_acum:1.364650 | lr:  1.1008e-04 | norm: 0.9250
# step 1865 | loss_acum:1.319321 | lr:  1.0993e-04 | norm: 0.9325
# step 1866 | loss_acum:1.243429 | lr:  1.0979e-04 | norm: 0.9459
# step 1867 | loss_acum:1.405384 | lr:  1.0964e-04 | norm: 1.0444
# step 1868 | loss_acum:1.351036 | lr:  1.0949e-04 | norm: 0.9210
# step 1869 | loss_acum:1.237206 | lr:  1.0935e-04 | norm: 0.8996
# step 1870 | loss_acum:1.272423 | lr:  1.0921e-04 | norm: 0.9264
# step 1871 | loss_acum:1.274300 | lr:  1.0907e-04 | norm: 0.8695
# step 1872 | loss_acum:1.323130 | lr:  1.0893e-04 | norm: 0.9403
# step 1873 | loss_acum:1.304280 | lr:  1.0879e-04 | norm: 0.9670
# step 1874 | loss_acum:1.288065 | lr:  1.0865e-04 | norm: 0.9955
# step 1875 | loss_acum:1.290476 | lr:  1.0851e-04 | norm: 1.0468
# step 1876 | loss_acum:1.292191 | lr:  1.0837e-04 | norm: 1.0450
# step 1877 | loss_acum:1.245911 | lr:  1.0824e-04 | norm: 0.9190
# step 1878 | loss_acum:1.276313 | lr:  1.0810e-04 | norm: 0.9030
# step 1879 | loss_acum:1.273356 | lr:  1.0797e-04 | norm: 0.8839
# step 1880 | loss_acum:1.335271 | lr:  1.0784e-04 | norm: 0.9045
# step 1881 | loss_acum:1.258042 | lr:  1.0771e-04 | norm: 0.9017
# step 1882 | loss_acum:1.365756 | lr:  1.0758e-04 | norm: 0.9722
# step 1883 | loss_acum:1.311881 | lr:  1.0745e-04 | norm: 0.9744
# step 1884 | loss_acum:1.304209 | lr:  1.0732e-04 | norm: 0.9443
# step 1885 | loss_acum:1.332372 | lr:  1.0720e-04 | norm: 0.9184
# step 1886 | loss_acum:1.329918 | lr:  1.0707e-04 | norm: 0.9490
# step 1887 | loss_acum:1.341325 | lr:  1.0695e-04 | norm: 1.0750
# step 1888 | loss_acum:1.334858 | lr:  1.0682e-04 | norm: 0.9606
# step 1889 | loss_acum:1.361218 | lr:  1.0670e-04 | norm: 0.8948
# step 1890 | loss_acum:1.274968 | lr:  1.0658e-04 | norm: 0.9644
# step 1891 | loss_acum:1.301392 | lr:  1.0646e-04 | norm: 0.9305
# step 1892 | loss_acum:1.258645 | lr:  1.0634e-04 | norm: 0.9679
# step 1893 | loss_acum:1.310257 | lr:  1.0622e-04 | norm: 0.9551
# step 1894 | loss_acum:1.228629 | lr:  1.0611e-04 | norm: 0.9844
# step 1895 | loss_acum:1.292748 | lr:  1.0599e-04 | norm: 0.9192
# step 1896 | loss_acum:1.311510 | lr:  1.0588e-04 | norm: 0.9063
# step 1897 | loss_acum:1.306315 | lr:  1.0576e-04 | norm: 0.9532
# step 1898 | loss_acum:1.359563 | lr:  1.0565e-04 | norm: 0.9937
# step 1899 | loss_acum:1.235730 | lr:  1.0554e-04 | norm: 0.8999
# step 1900 | loss_acum:1.307978 | lr:  1.0543e-04 | norm: 0.9268
# step 1901 | loss_acum:1.288845 | lr:  1.0532e-04 | norm: 1.0044
# step 1902 | loss_acum:1.295584 | lr:  1.0521e-04 | norm: 0.9274
# step 1903 | loss_acum:1.353761 | lr:  1.0511e-04 | norm: 0.9796
# step 1904 | loss_acum:1.306989 | lr:  1.0500e-04 | norm: 0.9807
# step 1905 | loss_acum:1.325699 | lr:  1.0490e-04 | norm: 0.9313
# step 1906 | loss_acum:1.309827 | lr:  1.0479e-04 | norm: 0.9049
# step 1907 | loss_acum:1.318562 | lr:  1.0469e-04 | norm: 0.9207
# step 1908 | loss_acum:1.338205 | lr:  1.0459e-04 | norm: 0.9310
# step 1909 | loss_acum:1.353624 | lr:  1.0449e-04 | norm: 1.0418
# step 1910 | loss_acum:1.302180 | lr:  1.0439e-04 | norm: 0.9072
# step 1911 | loss_acum:1.312274 | lr:  1.0429e-04 | norm: 1.0183
# step 1912 | loss_acum:1.276590 | lr:  1.0420e-04 | norm: 0.9292
# step 1913 | loss_acum:1.288557 | lr:  1.0410e-04 | norm: 0.9272
# step 1914 | loss_acum:1.304978 | lr:  1.0401e-04 | norm: 0.9516
# step 1915 | loss_acum:1.315395 | lr:  1.0391e-04 | norm: 0.9627
# step 1916 | loss_acum:1.296060 | lr:  1.0382e-04 | norm: 0.9342
# step 1917 | loss_acum:1.305049 | lr:  1.0373e-04 | norm: 0.9355
# step 1918 | loss_acum:1.322788 | lr:  1.0364e-04 | norm: 1.0082
# step 1919 | loss_acum:1.307463 | lr:  1.0355e-04 | norm: 0.9805
# step 1920 | loss_acum:1.392139 | lr:  1.0346e-04 | norm: 0.9713
# step 1921 | loss_acum:1.302104 | lr:  1.0337e-04 | norm: 0.9825
# step 1922 | loss_acum:1.257359 | lr:  1.0329e-04 | norm: 0.9024
# step 1923 | loss_acum:1.249187 | lr:  1.0320e-04 | norm: 0.9470
# step 1924 | loss_acum:1.302853 | lr:  1.0312e-04 | norm: 0.9283
# step 1925 | loss_acum:1.347846 | lr:  1.0304e-04 | norm: 1.0228
# step 1926 | loss_acum:1.294788 | lr:  1.0296e-04 | norm: 0.9537
# step 1927 | loss_acum:1.280363 | lr:  1.0288e-04 | norm: 0.9737
# step 1928 | loss_acum:1.297258 | lr:  1.0280e-04 | norm: 0.9689
# step 1929 | loss_acum:1.362667 | lr:  1.0272e-04 | norm: 0.9747
# step 1930 | loss_acum:1.305713 | lr:  1.0264e-04 | norm: 0.9797
# step 1931 | loss_acum:1.337535 | lr:  1.0257e-04 | norm: 0.9288
# step 1932 | loss_acum:1.275397 | lr:  1.0249e-04 | norm: 0.9110
# step 1933 | loss_acum:1.268546 | lr:  1.0242e-04 | norm: 0.8876
# step 1934 | loss_acum:1.280912 | lr:  1.0234e-04 | norm: 0.9606
# step 1935 | loss_acum:1.306855 | lr:  1.0227e-04 | norm: 0.9817
# step 1936 | loss_acum:1.293204 | lr:  1.0220e-04 | norm: 0.9534
# step 1937 | loss_acum:1.268404 | lr:  1.0213e-04 | norm: 0.9504
# step 1938 | loss_acum:1.312258 | lr:  1.0207e-04 | norm: 0.9921
# step 1939 | loss_acum:1.282142 | lr:  1.0200e-04 | norm: 0.9051
# step 1940 | loss_acum:1.334054 | lr:  1.0193e-04 | norm: 0.9823
# step 1941 | loss_acum:1.280247 | lr:  1.0187e-04 | norm: 0.9876
# step 1942 | loss_acum:1.303352 | lr:  1.0180e-04 | norm: 1.0214
# step 1943 | loss_acum:1.236986 | lr:  1.0174e-04 | norm: 0.8765
# step 1944 | loss_acum:1.300064 | lr:  1.0168e-04 | norm: 0.9635
# step 1945 | loss_acum:1.254496 | lr:  1.0162e-04 | norm: 0.9306
# step 1946 | loss_acum:1.243907 | lr:  1.0156e-04 | norm: 0.9259
# step 1947 | loss_acum:1.286618 | lr:  1.0150e-04 | norm: 0.9737
# step 1948 | loss_acum:1.310583 | lr:  1.0144e-04 | norm: 0.9659
# step 1949 | loss_acum:1.302223 | lr:  1.0139e-04 | norm: 0.9450
# step 1950 | loss_acum:1.333334 | lr:  1.0133e-04 | norm: 0.9879
# step 1951 | loss_acum:1.271669 | lr:  1.0128e-04 | norm: 0.8850
# step 1952 | loss_acum:1.354192 | lr:  1.0123e-04 | norm: 0.9801
# step 1953 | loss_acum:1.329936 | lr:  1.0118e-04 | norm: 0.9902
# step 1954 | loss_acum:1.309380 | lr:  1.0112e-04 | norm: 1.0265
# step 1955 | loss_acum:1.297197 | lr:  1.0108e-04 | norm: 0.9287
# step 1956 | loss_acum:1.330935 | lr:  1.0103e-04 | norm: 0.9483
# step 1957 | loss_acum:1.309348 | lr:  1.0098e-04 | norm: 0.9518
# step 1958 | loss_acum:1.315816 | lr:  1.0093e-04 | norm: 0.9607
# step 1959 | loss_acum:1.232426 | lr:  1.0089e-04 | norm: 0.9476
# step 1960 | loss_acum:1.287926 | lr:  1.0085e-04 | norm: 0.9441
# step 1961 | loss_acum:1.309967 | lr:  1.0080e-04 | norm: 0.9502
# step 1962 | loss_acum:1.283140 | lr:  1.0076e-04 | norm: 0.9786
# step 1963 | loss_acum:1.352859 | lr:  1.0072e-04 | norm: 1.0313
# step 1964 | loss_acum:1.296520 | lr:  1.0068e-04 | norm: 0.9654
# step 1965 | loss_acum:1.359803 | lr:  1.0064e-04 | norm: 1.0177
# step 1966 | loss_acum:1.350478 | lr:  1.0061e-04 | norm: 1.0014
# step 1967 | loss_acum:1.300386 | lr:  1.0057e-04 | norm: 0.9934
# step 1968 | loss_acum:1.325845 | lr:  1.0053e-04 | norm: 0.9537
# step 1969 | loss_acum:1.332819 | lr:  1.0050e-04 | norm: 0.9970
# step 1970 | loss_acum:1.223963 | lr:  1.0047e-04 | norm: 0.9355
# step 1971 | loss_acum:1.314245 | lr:  1.0044e-04 | norm: 1.0159
# step 1972 | loss_acum:1.271293 | lr:  1.0041e-04 | norm: 0.9953
# step 1973 | loss_acum:1.307634 | lr:  1.0038e-04 | norm: 0.9219
# step 1974 | loss_acum:1.304334 | lr:  1.0035e-04 | norm: 0.9187
# step 1975 | loss_acum:1.331654 | lr:  1.0032e-04 | norm: 1.0228
# step 1976 | loss_acum:1.273558 | lr:  1.0029e-04 | norm: 0.9160
# step 1977 | loss_acum:1.305898 | lr:  1.0027e-04 | norm: 0.9363
# step 1978 | loss_acum:1.324066 | lr:  1.0025e-04 | norm: 0.9931
# step 1979 | loss_acum:1.286883 | lr:  1.0022e-04 | norm: 0.9183
# step 1980 | loss_acum:1.327437 | lr:  1.0020e-04 | norm: 0.9659
# step 1981 | loss_acum:1.299174 | lr:  1.0018e-04 | norm: 0.9518
# step 1982 | loss_acum:1.323504 | lr:  1.0016e-04 | norm: 0.9506
# step 1983 | loss_acum:1.383530 | lr:  1.0014e-04 | norm: 1.0081
# step 1984 | loss_acum:1.237201 | lr:  1.0013e-04 | norm: 0.9116
# step 1985 | loss_acum:1.232770 | lr:  1.0011e-04 | norm: 0.9084
# step 1986 | loss_acum:1.334878 | lr:  1.0009e-04 | norm: 0.9853
# step 1987 | loss_acum:1.328783 | lr:  1.0008e-04 | norm: 0.8800
# step 1988 | loss_acum:1.266986 | lr:  1.0007e-04 | norm: 0.9347
# step 1989 | loss_acum:1.350996 | lr:  1.0006e-04 | norm: 0.9600
# step 1990 | loss_acum:1.240379 | lr:  1.0005e-04 | norm: 0.9257
# step 1991 | loss_acum:1.304366 | lr:  1.0004e-04 | norm: 0.9628
# step 1992 | loss_acum:1.211255 | lr:  1.0003e-04 | norm: 0.9560
# step 1993 | loss_acum:1.253844 | lr:  1.0002e-04 | norm: 0.9162
# step 1994 | loss_acum:1.291659 | lr:  1.0001e-04 | norm: 0.9412
# step 1995 | loss_acum:1.256525 | lr:  1.0001e-04 | norm: 0.8952
# step 1996 | loss_acum:1.373918 | lr:  1.0001e-04 | norm: 1.0717
# step 1997 | loss_acum:1.273100 | lr:  1.0000e-04 | norm: 0.9892
# step 1998 | loss_acum:1.342877 | lr:  1.0000e-04 | norm: 0.9734
# step 1999 | loss_acum:1.274220 | lr:  1.0000e-04 | norm: 0.8995

# %%
losses['train'],losses['val'] #last recorded Train Val Loss
# Out:
# (tensor(1.3115), tensor(1.5269))

# %%
print(epoch)
# Out:
# 40

# %%
for i in range(5):
    context = torch.zeros(1,1 , dtype = torch.long, device = device)
    out = decoder(model.generate(context, 300).tolist()[0])
    print(out)
# Out:
# ne's toward king!
#
# RICHMOND:
# Hold received the grant are well caught her,
# Side even chysel. Have wask me her one safe
# Than I was acpin to your viols talk in
# His upon you: I own mean bhild up awas than thee
# are is of fak! my tongued and doings; for eath
# of m
# ion,
# More to one so not lightly spirits,
# But save appriof at officersation me
# To swill givil out enter to the mileguable,
# Being and to-night root aritoroous be thus
# Time letters for him up to me a
# For some left by of late him that took find appear,
# Ere devi
#
# Thou should I think what he asvices; therefore
# To bear enmity, that to slow their do
# that the bover of all-hood your limbs:
# You wilt first.
#
# ANGELO:
# If my best, 'let y--
#
#
# ISABELLA:
# O the city; enough, look to hear shall be comes!--
#
# BENVOLIO:
# For Marcius:
# ays to fine mad, sit by this ours.
# To fleser, pardon, truspetitlut, the soon.
#
# SICINIUS:
# Now it is sow; since take you of thy mother's
# With slain off, let I have drownrage, let you
# do.
#
# MENENIUS:
# O--Mercy, if you,
# Love's where to give me and me towards with
# QUEEN MARGARET:
# We will, it issue and it is their crown;
# And and misselGuclary from a lady from well,
# The clamortors, sake we fill me measure in wife.
#
# QUEEN MARGARET:
# Yea, no, what a marriage of my Gloucester
# With a hrouble south to the pridence command;
# H

# %%
@torch.no_grad()
def estimate_loss1():
    model.eval()
    out = {}
    for split in ['train','val','test']:
        losses = torch.zeros(KFold_iters)
        for i in range(KFold_iters):
            xb,yb = get_batch(split)
            logits,loss = model.forward(xb,yb)
            losses[i] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# %%
losses = estimate_loss1()
print(f" train loss {losses['train']:.4f}, val loss {losses['val']:.4f},  dev loss {losses['test']:.4f}")
# Out:
#  train loss 1.3055, val loss 1.5195,  dev loss 1.7704
